# %%
import sys
dw_path = "/home/emmanuel/ecastillo/dev/delaware/10102024"
sys.path.append(dw_path)

# %%
from obspy import UTCDateTime
from delaware.core.client import CustomClient
import pandas as pd

provider = "USGS"
client =  CustomClient(provider)
region = [-104.84329,-103.79942,31.39610,31.91505]
# region = [-103.973638,-103.963891,31.607104,31.614540]

cat,picks,mag = client.get_custom_events(
                        minlatitude=region[2], maxlatitude=region[3], 
                        minlongitude=region[0], maxlongitude=region[1],
                        includeallorigins=True,
                        starttime=UTCDateTime(f"2024-01-01 15:26:30"),
                        endtime=UTCDateTime("2024-09-30 15:26:32"))
columns = []

cat.columns = cat.columns.get_level_values(1)
cat = cat.rename(columns={"latitude":"eq_latitude","longitude":"eq_longitude"})

picks["arrival_time"] = pd.to_datetime(picks["arrival_time"])
cat["origin_time"] = pd.to_datetime(cat["origin_time"])

cat_columns = ["ev_id","origin_time","eq_latitude","eq_longitude","magnitude"]
picks_columns = ["ev_id","station","phase_hint","arrival_time"]

cat = cat.drop_duplicates(ignore_index=True, keep="first")
picks = picks.dropna(subset="phase_hint")
picks= picks[picks["phase_hint"].isin(["P","S"])]
picks = picks.drop_duplicates(subset=(["ev_id", "station", "phase_hint"]),ignore_index=True)

cat = cat[cat_columns]
picks[picks_columns]
print("### catalog ###\n",cat)
print("### picks ###\n",picks)
# Out:
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.242054.288035'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.242256.288036'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.242401.288037'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.242505.288038'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.242637.288039'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.242733.288040'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.242878.288041'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.242981.288042'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.243086.288043'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.243183.288044'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.243296.288045'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.243394.288046'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.24351.288047'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.243607.288048'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.243754.288049'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.243901.288050'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.244015.288051'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.244118.288052'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.244218.288053'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.244312.288054'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.244417.288055'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.244512.288056'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.244621.288057'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.244716.288058'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.244814.288059'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.244903.288060'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.245018.288061'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.245121.288062'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.245224.288063'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.245315.288064'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.245414.288065'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.245505.288066'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.245595.288067'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240206193535.245686.288068'
# Event: texnet2024cnov | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20
Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.964445.116419'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.964528.116420'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.964609.116421'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.964688.116422'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.964768.116423'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.964847.116424'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.964926.116425'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.96501.116426'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.965092.116427'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.965168.116428'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.965251.116429'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.965334.116430'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.965418.116431'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.965499.116432'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.965582.116433'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.965663.116434'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.965746.116435'
# Event: texnet2024supa | Pick not found: 'smi:org.gfz-potsdam.de/geofon/Pick/20240924122959.965828.116436'
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/client.py:700: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_origins = pd.concat(all_origins, axis=0)
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/client.py:701: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_picks = pd.concat(all_picks, axis=0)
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/client.py:702: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_mags = pd.concat(all_mags, axis=0)
# ### catalog ###
#                 ev_id                origin_time  eq_latitude  eq_longitude  \
# 0     texnet2024abfc 2024-01-01 15:42:34.991993       31.661      -104.491
# 1     texnet2024aboa 2024-01-01 20:13:17.460065       31.657      -104.329
# 2     texnet2024abrd 2024-01-01 21:47:07.938951       31.609      -103.976
# 3     texnet2024absh 2024-01-01 22:22:45.982513       31.615      -103.971
# 4     texnet2024aciy 2024-01-02 06:47:34.492563       31.652      -104.254
# ...              ...                        ...          ...           ...
# 2930  texnet2024telk 2024-09-29 19:27:35.789774       31.518      -104.014
# 2931  texnet2024tels 2024-09-29 19:36:01.242223       31.532      -104.011
# 2932  texnet2024tflx 2024-09-30 08:51:46.240391       31.666      -104.455
# 2933  texnet2024tfoo 2024-09-30 10:10:23.137146       31.631      -104.121
# 2934  texnet2024tfux 2024-09-30 13:25:52.054337       31.659      -104.408
#
#       magnitude
# 0           1.9
# 1           1.7
# 2           1.7
# 3           1.7
# 4           2.1
# ...         ...
# 2930        2.0
# 2931        1.6
# 2932        1.4
# 2933        1.7
# 2934        1.9
#
# [2935 rows x 5 columns]
# ### picks ###
#                   ev_id network station location channel phase_hint  \
# 0       texnet2024abfc      TX    PB28       00     HHZ          P
# 1       texnet2024abfc      TX    PB28       00     HHZ          S
# 2       texnet2024abfc      TX    PB35       00     HH1          S
# 3       texnet2024abfc      TX    PB35       00     HHZ          P
# 4       texnet2024abfc      TX    PB37       00     HHZ          P
# ...                ...     ...     ...      ...     ...        ...
# 135535  texnet2024tfux      TX    PECS       00     HHR          P
# 135536  texnet2024tfux      TX    PB12       00     HHR          P
# 135537  texnet2024tfux      TX    PB12       00     HHR          S
# 135538  texnet2024tfux      TX    VHRN       00     HHT          S
# 135539  texnet2024tfux      TX    VHRN       00     HHR          P
#
#                      arrival_time  time_lower_error  time_upper_error author  \
# 0      2024-01-01 15:42:36.629131               0.2               0.2     JJ
# 1      2024-01-01 15:42:37.517726               0.3               0.3     JJ
# 2      2024-01-01 15:42:38.024380               0.3               0.3     JJ
# 3      2024-01-01 15:42:37.003276               0.2               0.2     JJ
# 4      2024-01-01 15:42:37.237117               0.2               0.2     JJ
# ...                           ...               ...               ...    ...
# 135535 2024-09-30 13:26:02.937831               0.1               0.1  JessD
# 135536 2024-09-30 13:26:03.761682               0.1               0.1  JessD
# 135537 2024-09-30 13:26:11.744522               0.1               0.1  JessD
# 135538 2024-09-30 13:26:24.201730               0.1               0.1  JessD
# 135539 2024-09-30 13:26:10.807036               0.1               0.1  JessD
#
#         ... polarity evaluation_mode evaluation_status time_correction  \
# 0       ...     None          manual              None             0.0
# 1       ...     None          manual              None             0.0
# 2       ...     None          manual              None             0.0
# 3       ...     None          manual              None             0.0
# 4       ...     None          manual              None             0.0
# ...     ...      ...             ...               ...             ...
# 135535  ...     None          manual              None             0.0
# 135536  ...     None          manual              None             0.0
# 135537  ...     None          manual              None             0.0
# 135538  ...     None          manual              None             0.0
# 135539  ...     None          manual              None             0.0
#
#            azimuth  distance  takeoff_angle  time_residual  time_weight  used
# 0       311.454449  0.010881          167.6       0.058911     1.335565  True
# 1       311.454449  0.010881          167.6      -0.236238     1.166528  True
# 2        96.460273  0.050669          137.0      -0.375962     1.031916  True
# 3        96.460273  0.050669          137.0       0.063699     1.329989  True
# 4       331.405157  0.065364          126.4       0.074480     1.316541  True
# ...            ...       ...            ...            ...          ...   ...
# 135535  122.268593  0.544776           79.5      -0.147423     1.424643  True
# 135536  139.506813  0.589070           79.5      -0.178559     1.380939  True
# 135537  139.506813  0.589070           79.4      -1.110969     0.132146  True
# 135538  210.077621  1.002934           71.4      -2.217410     0.002806  True
# 135539  210.077621  1.002934           71.4      -0.882694     0.222216  True
#
# [135540 rows x 22 columns]

# %%
import pandas as pd
stations_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/stations/standard_stations.csv"
stations = pd.read_csv(stations_path)
stations_columns = ["network","station","latitude","longitude","elevation","x[km]","y[km]"]

picks_sta = pd.merge(picks,stations,on=["network","station"],how="inner")
new_cols = stations_columns
new_cols.remove("station")
picks_sta = picks_sta[picks_columns+new_cols]
picks_sta[0:10]
# Out:
#             ev_id station phase_hint               arrival_time network  \
# 0  texnet2024abfc    PB28          P 2024-01-01 15:42:36.629131      TX
# 1  texnet2024abfc    PB28          S 2024-01-01 15:42:37.517726      TX
# 2  texnet2024abfc    PB35          S 2024-01-01 15:42:38.024380      TX
# 3  texnet2024abfc    PB35          P 2024-01-01 15:42:37.003276      TX
# 4  texnet2024abfc    PB37          P 2024-01-01 15:42:37.237117      TX
# 5  texnet2024abfc    PB37          S 2024-01-01 15:42:38.492062      TX
# 6  texnet2024abfc    PB29          S 2024-01-01 15:42:39.435219      TX
# 7  texnet2024abfc    PB29          P 2024-01-01 15:42:37.704798      TX
# 8  texnet2024abfc    SA02          P 2024-01-01 15:42:39.552140      4O
# 9  texnet2024abfc    SA02          S 2024-01-01 15:42:41.882751      4O
                              lat2_name: str, lon2_name: str,columns=None):
    """
    Compute distances between two sets of latitude and longitude coordinates in a DataFrame.

    Args:
    - data (pd.DataFrame): Input DataFrame containing the latitude and longitude columns.
    - lat1_name (str): Name of the column containing the first set of latitudes.
    - lon1_name (str): Name of the column containing the first set of longitudes.
    - lat2_name (str): Name of the column containing the second set of latitudes.
    - lon2_name (str): Name of the column containing the second set of longitudes.
    - columns (list): Default:None means 'r','az','baz'. 3d List representing distance, azimuth y back azimuth

    Returns:
    - pd.DataFrame: DataFrame with additional columns 'r', 'az', 'baz' representing distance (in km),
      azimuth (degrees clockwise from north), and back azimuth (degrees clockwise from south), respectively.
    """
    if data.empty:
        return data
    
    data = data.reset_index(drop=True)
    computing_r = lambda x: gps2dist_azimuth(x[lat1_name], x[lon1_name],
                                             x[lat2_name], x[lon2_name])
    r = data.apply(computing_r, axis=1)
    
    if columns is None:
        columns = ["r", "az", "baz"]
        
    data[columns] = pd.DataFrame(r.tolist(), index=data.index)
    data[columns[0]] = data[columns[0]] / 1e3
    return data

picks_r_tt = get_distance_in_dataframe(data=picks_eq,lat1_name="latitude",
                                         lon1_name="longitude",lat2_name="eq_latitude",
                                         lon2_name="eq_longitude")

picks_r_tt["tt"] = picks_r_tt["arrival_time"] - picks_r_tt["origin_time"]
picks_r_tt["tt"] = picks_r_tt["tt"].dt.total_seconds()

picks_r_tt = picks_r_tt[picks_columns+["tt","r"]]
picks_r_tt.reset_index(inplace=True,drop=True)
picks_r_tt
# Out:
# /tmp/ipykernel_32096/3611965819.py:24: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   computing_r = lambda x: gps2dist_azimuth(x[lat1_name], x[lon1_name],
#                 ev_id station phase_hint               arrival_time  \
# 0      texnet2024abfc    PB28          P 2024-01-01 15:42:36.629131
# 1      texnet2024abfc    PB28          S 2024-01-01 15:42:37.517726
# 2      texnet2024abfc    PB35          S 2024-01-01 15:42:38.024380
# 3      texnet2024abfc    PB35          P 2024-01-01 15:42:37.003276
# 4      texnet2024abfc    PB37          P 2024-01-01 15:42:37.237117
# ...               ...     ...        ...                        ...
# 98232  texnet2024tfux    PB23          P 2024-09-30 13:25:59.035833
# 98233  texnet2024tfux    PB20          P 2024-09-30 13:25:59.127562
# 98234  texnet2024tfux    PB20          S 2024-09-30 13:26:03.206791
# 98235  texnet2024tfux    PB33          S 2024-09-30 13:26:03.654642
# 98236  texnet2024tfux    PB33          P 2024-09-30 13:25:59.203103
#
#               tt          r
# 0       1.637138   1.255431
# 1       2.525733   1.255431
# 2       3.032387   5.618213
# 3       2.011283   5.618213
# 4       2.245124   7.293216
# ...          ...        ...
# 98232   6.981496  31.798599
# 98233   7.073225  33.018627
# 98234  11.152454  33.018627
# 98235  11.600305  36.299599
# 98236   7.148766  36.299599
#
# [98237 rows x 6 columns]

# %%
picks_ready = picks_r_tt.pivot(index=["ev_id", "station", "r"], columns="phase_hint", 
                      values=["arrival_time", "tt"]).reset_index()
# Flatten multi-level columns
picks_ready.columns = ['_'.join(col).strip('_') for col in picks_ready.columns.values]
picks_ready.dropna(subset=["tt_P","tt_S"],inplace=True)
picks_ready.sort_values(by="tt_P",inplace=True,ignore_index=True)
picks_ready
# Out:
#                 ev_id station          r             arrival_time_P  \
# 0      texnet2024bpyp    PB39  23.006084 2024-01-23 22:57:42.100564
# 1      texnet2024drvw    SA02   8.553056 2024-02-22 10:58:12.497863
# 2      texnet2024mijb    WB02  14.745552 2024-06-24 08:06:08.643942
# 3      texnet2024dcwo    PB35   2.669546 2024-02-14 06:17:37.622656
# 4      texnet2024cxib    PB24   1.266370 2024-02-11 05:14:55.131428
# ...               ...     ...        ...                        ...
# 44729  texnet2024rhib    WB04  78.293251 2024-09-02 22:08:07.663011
# 44730  texnet2024gapq    PB34  56.710140 2024-03-26 17:07:52.410697
# 44731  texnet2024gapq    PB20  55.452499 2024-03-26 17:07:52.475149
# 44732  texnet2024gapq    PB23  53.638186 2024-03-26 17:07:52.947507
# 44733  texnet2024gapq    PB26  51.280438 2024-03-26 17:07:53.571021
#
#                   arrival_time_S       tt_P       tt_S
# 0     2024-01-23 22:57:49.492235   0.148385   7.540056
# 1     2024-02-22 10:58:16.195258   0.522639   4.220034
# 2     2024-06-24 08:06:13.682199   0.602305   5.640562
# 3     2024-02-14 06:17:38.770369   0.648776   1.796489
# 4     2024-02-11 05:14:55.594401   0.763484   1.226457
# ...                          ...        ...        ...
# 44729 2024-09-02 22:08:17.585021  14.512216  24.434226
# 44730 2024-03-26 17:07:53.544951  14.560143  15.694397
# 44731 2024-03-26 17:07:53.696983  14.624595  15.846429
# 44732 2024-03-26 17:07:53.841840  15.096953  15.991286
# 44733 2024-03-26 17:07:55.601346  15.720467  17.750792
#
# [44734 rows x 7 columns]

# %%
import numpy as np

def loss_function(particles, r, tp_obs, ts_obs):
    z_guess = particles[:, 0]
    vp_guess = particles[:, 1]
    vs_guess = particles[:, 2]

    if np.any(vp_guess == 0):
        raise Exception("vp_guess must not contain any zeros")
    if np.any(vs_guess == 0):
        raise Exception("vs_guess must not contain any zeros")

    tp_pred = np.sqrt(r**2 + z_guess**2) / vp_guess
    ts_pred = np.sqrt(r**2 + z_guess**2) / vs_guess
    loss = ((tp_pred - tp_obs)**2) + ((ts_pred - ts_obs)**2)
    return loss

def vd_pso(cost_func,
           picks,
           bounds,
           max_iter=100,w=0.5,c1=0.8,c2=0.9):
    
    n_particles = len(picks)
    dim = bounds.shape[-1]
    
    particles = np.random.uniform(low=bounds[0], high=bounds[1], size=(n_particles, dim))
    velocities = np.zeros((n_particles, dim))
    args = {col: picks[col].to_numpy() for col in ["r",'tt_P','tt_S']}
    
    # Initialize the particles and velocities
    particles = np.random.uniform(low=bounds[0], high=bounds[1], size=(n_particles, 3))
    velocities = np.zeros((n_particles, 3))

    # Initialize the best positions and best costs
    best_positions = particles.copy()
    best_costs = cost_func(
                            particles=particles,
                            r=args["r"],
                            tp_obs=args["tt_P"],
                            ts_obs=args["tt_S"]
                        )

    # Initialize the global best position and global best cost
    global_best_position = particles[0].copy()
    global_best_cost = best_costs[0]

    # Perform the optimization
    for i in range(max_iter):
        # Update the velocities
        r1 = np.random.rand(n_particles, 3) #Random matrix used to compute the cognitive component of the veocity update
        r2 = np.random.rand(n_particles, 3) #Random matrix used to compute the social component of the veocity update


        #Cognitive component is calculated by taking the difference between the
        #particle's current position and its best personal position found so far,
        #and then multiplying it by a random matrix r1 and a cognitive acceleration coefficient c1.
        cognitive_component = c1 * r1 * (best_positions - particles)

        #The social component represents the particle's tendency to move towards the
        #global best position found by the swarm. It is calculated by taking the
        #difference between the particle's current position and the global best position
        # found by the swarm, and then multiplying it by a random matrix r2 and a
        #social acceleration coefficient c2.
        social_component = c2 * r2 * (global_best_position - particles)

        #The new velocity of the particle is computed by adding the current velocity
        #to the sum of the cognitive and social components, multiplied by the inertia
        #weight w. The new velocity is then used to update the position of the
        #particle in the search space.
        velocities = w * velocities + cognitive_component + social_component

        # Update the particles
        particles += velocities

        # Enforce the bounds of the search space
        particles = np.clip(particles, bounds[0], bounds[1])

        # Evaluate the objective function
        costs = cost_func(
                            particles=particles,
                            r=args["r"],
                            tp_obs=args["tt_P"],
                            ts_obs=args["tt_S"]
                        )

        # Update the best positions and best costs
        is_best = costs < best_costs
        best_positions[is_best] = particles[is_best]
        best_costs[is_best] = costs[is_best]

        # Update the global best position and global best cost
        global_best_index = np.argmin(best_costs)
        global_best_position = best_positions[global_best_index].copy()
        global_best_cost = best_costs[global_best_index]

        # Print the progress
        if (i+1)%10 == 0:
            print(f'Iteration {i+1}: Best Cost = {global_best_cost:.6f} | sol:{global_best_position}')
    
    return global_best_position, global_best_cost



cost_func = loss_function
bounds = np.array([[0,2.5,1.2],[10,6,3.5]])

# Run the PSO algorithm on the Rastrigin function
solution, fitness = vd_pso(cost_func=cost_func,picks=picks_ready,
                            bounds=bounds,max_iter=500
                            )

solution, fitness
# Out:
# Iteration 10: Best Cost = 0.000002 | sol:[3.19151061 3.31230436 2.06406934]
# Iteration 20: Best Cost = 0.000001 | sol:[3.12757561 3.33727015 2.01913241]
# Iteration 30: Best Cost = 0.000000 | sol:[3.20217537 3.50840919 2.03680091]
# Iteration 40: Best Cost = 0.000000 | sol:[2.96558222 3.15756352 2.05823552]
# Iteration 50: Best Cost = 0.000000 | sol:[2.96527181 3.1580291  2.05833776]
# Iteration 60: Best Cost = 0.000000 | sol:[2.96538331 3.15798205 2.05822537]
# Iteration 70: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 80: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 90: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 100: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 110: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 120: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 130: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 140: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 150: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 160: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 170: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 180: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 190: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 200: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 210: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 220: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 230: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 240: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 250: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 260: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 270: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 280: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 290: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 300: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 310: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 320: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 330: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 340: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 350: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 360: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 370: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 380: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 390: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 400: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 410: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 420: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 430: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 440: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 450: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 460: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 470: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 480: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 490: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# Iteration 500: Best Cost = 0.000000 | sol:[2.96538359 3.15798191 2.05822499]
# (array([2.96538359, 3.15798191, 2.05822499]), 2.7529420084616973e-08)

# %%
import numpy as np

def loss_function(particles, r, tp_obs, ts_obs):
    z_guess = particles[:, 0]
    vp_guess = particles[:, 1]
    vs_guess = particles[:, 2]

    if np.any(vp_guess == 0):
        raise Exception("vp_guess must not contain any zeros")
    if np.any(vs_guess == 0):
        raise Exception("vs_guess must not contain any zeros")

    tp_pred = np.sqrt(r**2 + z_guess**2) / vp_guess
    ts_pred = np.sqrt(r**2 + z_guess**2) / vs_guess
    loss = ((tp_pred - tp_obs)**2) + ((ts_pred - ts_obs)**2)
    return loss

def gradient(loss_func, particles, r, tp_obs, ts_obs, epsilon=1e-6):
    """Calculate gradients for the loss function w.r.t. particles."""
    gradients = np.zeros_like(particles)
    for i in range(particles.shape[1]):
        # Perturb each parameter by a small epsilon and calculate the gradient
        particles_plus = particles.copy()
        particles_plus[:, i] += epsilon
        loss_plus = loss_func(particles_plus, r, tp_obs, ts_obs)
        
        particles_minus = particles.copy()
        particles_minus[:, i] -= epsilon
        loss_minus = loss_func(particles_minus, r, tp_obs, ts_obs)
        
        # Compute the gradient (difference between perturbed losses)
        gradients[:, i] = (loss_plus - loss_minus) / (2 * epsilon)
        
    return gradients

def vd_gradient_descent(cost_func, picks, bounds, max_iter=100, lr=0.01):
    n_particles = len(picks)
    dim = bounds.shape[-1]
    
    particles = np.random.uniform(low=bounds[0], high=bounds[1], size=(n_particles, dim))
    args = {col: picks[col].to_numpy() for col in ["r", 'tt_P', 'tt_S']}
    
    # Initialize the best position and best cost
    costs = cost_func(particles=particles, r=args["r"], tp_obs=args["tt_P"], ts_obs=args["tt_S"])
    best_cost = np.min(costs)
    best_position = particles[np.argmin(costs)].copy()

    # Perform gradient descent optimization
    for i in range(max_iter):
        # Compute gradients of the loss function
        gradients = gradient(cost_func, particles, args["r"], args["tt_P"], args["tt_S"])
        
        # Update particles using gradient descent
        particles -= lr * gradients

        # Enforce the bounds of the search space
        particles = np.clip(particles, bounds[0], bounds[1])

        # Evaluate the new costs
        costs = cost_func(particles=particles, r=args["r"], tp_obs=args["tt_P"], ts_obs=args["tt_S"])

        # Update best position if new cost is lower
        current_best_cost = np.min(costs)
        if current_best_cost < best_cost:
            best_cost = current_best_cost
            best_position = particles[np.argmin(costs)].copy()

        # Print progress
        if (i + 1) % 10 == 0:
            print(f'Iteration {i+1}: Best Cost = {best_cost} | sol:{best_position}')

    return best_position, best_cost

# Example of how to call the Gradient Descent-based optimization function
bounds = np.array([[0, 2.5, 1.2], [10, 6, 3.5]])  # bounds for z_guess, vp_guess, vs_guess

# Call the function with your data (picks_ready should be a DataFrame or similar)
solution, fitness = vd_gradient_descent(cost_func=loss_function, picks=picks_ready, bounds=bounds, max_iter=500, lr=0.01)

print("Best Solution:", solution)
print("Best Fitness:", fitness)
# Out:
# Iteration 10: Best Cost = 7.925740188120402e-09 | sol:[6.78858581 4.58934908 2.83190295]
# Iteration 20: Best Cost = 7.05207980940181e-09 | sol:[6.78858392 4.58935775 2.83189998]
# Iteration 30: Best Cost = 2.6163183549477556e-11 | sol:[5.75276675 3.28248045 2.90703135]
# Iteration 40: Best Cost = 1.218205996484938e-16 | sol:[5.75276675 3.28247938 2.90703135]
# Iteration 370: Best Cost = 1.0874226697418186e-24 | sol:[5.33704121 4.29704612 3.27005865]
# Iteration 380: Best Cost = 1.0874226697418186e-24 | sol:[5.33704121 4.29704612 3.27005865]
# Iteration 390: Best Cost = 1.0874226697418186e-24 | sol:[5.33704121 4.29704612 3.27005865]
# Iteration 400: Best Cost = 1.0623905354973454e-24 | sol:[5.51980776 3.83916875 2.97949582]
# Iteration 410: Best Cost = 9.909867906612656e-25 | sol:[9.23628665 4.35806664 3.27314694]
# Iteration 420: Best Cost = 9.65117674996353e-25 | sol:[9.23628665 4.35806664 3.27314694]
# Iteration 430: Best Cost = 9.65117674996353e-25 | sol:[9.23628665 4.35806664 3.27314694]
# Iteration 440: Best Cost = 9.65117674996353e-25 | sol:[9.23628665 4.35806664 3.27314694]
# Iteration 450: Best Cost = 9.65117674996353e-25 | sol:[9.23628665 4.35806664 3.27314694]
# Iteration 460: Best Cost = 7.031369683724549e-25 | sol:[9.92316399 4.25636502 3.36222221]
# Iteration 470: Best Cost = 6.74532871949141e-25 | sol:[9.92316399 4.25636502 3.36222221]
# Iteration 480: Best Cost = 6.74532871949141e-25 | sol:[9.92316399 4.25636502 3.36222221]
# Iteration 490: Best Cost = 6.74532871949141e-25 | sol:[9.92316399 4.25636502 3.36222221]
# Iteration 500: Best Cost = 6.74532871949141e-25 | sol:[9.92316399 4.25636502 3.36222221]
# Best Solution: [9.92316399 4.25636502 3.36222221]
# Best Fitness: 6.74532871949141e-25

# %%
import numpy as np

def loss_function(particles, r, tp_obs, ts_obs):
    z_guess = particles[:, 0]
    # vp_guess = 4
    # vs_guess = 4/1.8
    vp_guess = particles[:, 1]
    vs_guess = particles[:, 2]

    if np.any(vp_guess == 0):
        raise Exception("vp_guess must not contain any zeros")
    if np.any(vs_guess == 0):
        raise Exception("vs_guess must not contain any zeros")

    tp_pred = np.sqrt(r**2 + z_guess**2) / vp_guess
    ts_pred = np.sqrt(r**2 + z_guess**2) / vs_guess
    loss = ((tp_pred - tp_obs)**2) + ((ts_pred - ts_obs)**2)
    return loss

def vd_adam(cost_func, picks, bounds, max_iter=100, lr=0.001, beta1=0.9, beta2=0.999, epsilon=1e-8):
    n_particles = len(picks)
    dim = bounds.shape[-1]
    
    particles = np.random.uniform(low=bounds[0], high=bounds[1], size=(n_particles, dim))
    args = {col: picks[col].to_numpy() for col in ["r", 'tt_P', 'tt_S']}
    
    # Initialize moment estimates
    m = np.zeros_like(particles)  # First moment (mean of gradients)
    v = np.zeros_like(particles)  # Second moment (uncentered variance of gradients)
    t = 0  # Time step (for bias correction)

    # Evaluate initial cost
    costs = cost_func(particles=particles, r=args["r"], tp_obs=args["tt_P"], ts_obs=args["tt_S"])
    best_cost = np.min(costs)
    best_position = particles[np.argmin(costs)].copy()

    # Perform Adam optimization
    for i in range(max_iter):
        t += 1  # Increment time step

        # Compute gradients (numerical approximation)
        gradients = gradient(cost_func, particles, args["r"], args["tt_P"], args["tt_S"])

        # Update moment estimates (bias correction applied to m and v)
        m = beta1 * m + (1 - beta1) * gradients  # Update first moment
        v = beta2 * v + (1 - beta2) * gradients**2  # Update second moment

        # Bias correction (to counteract initialization bias)
        m_hat = m / (1 - beta1**t)
        v_hat = v / (1 - beta2**t)

        # Update particles using Adam's update rule
        particles -= lr * m_hat / (np.sqrt(v_hat) + epsilon)

        # Enforce the bounds of the search space
        particles = np.clip(particles, bounds[0], bounds[1])

        # Evaluate new costs
        costs = cost_func(particles=particles, r=args["r"], tp_obs=args["tt_P"], ts_obs=args["tt_S"])

        # Update best position if new cost is lower
        current_best_cost = np.min(costs)
        if current_best_cost < best_cost:
            best_cost = current_best_cost
            best_position = particles[np.argmin(costs)].copy()

        # Print progress
        if (i + 1) % 10 == 0:
            print(f'Iteration {i+1}: Best Cost = {best_cost:.6f} | sol:{best_position}')

    return best_position, best_cost

def gradient(loss_func, particles, r, tp_obs, ts_obs, epsilon=1e-6):
    """Calculate gradients for the loss function w.r.t. particles."""
    gradients = np.zeros_like(particles)
    for i in range(particles.shape[1]):
        # Perturb each parameter by a small epsilon and calculate the gradient
        particles_plus = particles.copy()
        particles_plus[:, i] += epsilon
        loss_plus = loss_func(particles_plus, r, tp_obs, ts_obs)
        
        particles_minus = particles.copy()
        particles_minus[:, i] -= epsilon
        loss_minus = loss_func(particles_minus, r, tp_obs, ts_obs)
        
        # Compute the gradient (difference between perturbed losses)
        gradients[:, i] = (loss_plus - loss_minus) / (2 * epsilon)
        
    return gradients

# Example of how to call the Adam-based optimization function
bounds = np.array([[0, 2.5, 1.2], [10, 6, 3.5]])  # bounds for z_guess, vp_guess, vs_guess

# Call the function with your data (picks_ready should be a DataFrame or similar)
solution, fitness = vd_adam(cost_func=loss_function, picks=picks_ready, bounds=bounds, max_iter=500, lr=0.001)

print("Best Solution:", solution)
print("Best Fitness:", fitness)
# Out:
# Iteration 10: Best Cost = 0.000000 | sol:[9.48002354 4.69866726 3.11463057]
# Iteration 20: Best Cost = 0.000000 | sol:[9.48002354 4.69866726 3.11463057]
# Iteration 30: Best Cost = 0.000000 | sol:[9.48015734 4.69853058 3.11460186]
# Iteration 40: Best Cost = 0.000000 | sol:[9.48015734 4.69853058 3.11460186]
# Iteration 50: Best Cost = 0.000000 | sol:[8.81220944 5.63736888 3.37634223]
# Iteration 60: Best Cost = 0.000000 | sol:[8.81220944 5.63736888 3.37634223]
# Iteration 70: Best Cost = 0.000000 | sol:[9.48010013 4.69861388 3.11454195]
# Iteration 80: Best Cost = 0.000000 | sol:[3.97042874 5.20635909 2.99202836]
# Iteration 90: Best Cost = 0.000000 | sol:[8.81220953 5.63734031 3.37634886]
# Iteration 100: Best Cost = 0.000000 | sol:[9.48007241 4.69864445 3.11453486]
# Iteration 110: Best Cost = 0.000000 | sol:[9.48007919 4.69863665 3.11453776]
# Iteration 120: Best Cost = 0.000000 | sol:[9.48007592 4.69863984 3.11453819]
# Iteration 130: Best Cost = 0.000000 | sol:[9.12362178 5.08235243 2.99268264]
# Iteration 140: Best Cost = 0.000000 | sol:[9.12362178 5.08235243 2.99268264]
# Iteration 150: Best Cost = 0.000000 | sol:[4.59693778 3.15124213 1.79935036]
