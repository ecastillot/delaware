# %%
import sys
if 'google.colab' in sys.modules:
    # !git clone  https://github.com/ecastillot/delaware.git ./delaware
    # !pip install obspy

# %%
import sys
import os

version = "10102024"

if 'google.colab' in sys.modules:
    dw_path = os.path.join("/content/delaware",version)
else:
    dw_path = os.path.join("/home/emmanuel/ecastillo/dev/delaware",version)
    
sys.path.append(dw_path)

# %%
from delaware.core.read import EQPicks
from delaware.core.eqviewer import Stations
from delaware.loc.inv import prepare_cat2vps
import pandas as pd
import os
from itertools import combinations

import matplotlib.pyplot as plt
import seaborn as sns

def compute_vij(arrivals):
    # Ensure arrival times are in datetime format
    arrivals['arrival_time_P'] = pd.to_datetime(arrivals['arrival_time_P'])
    arrivals['arrival_time_S'] = pd.to_datetime(arrivals['arrival_time_S'])
    
    # List to store results
    results = []

    # Iterate over all combinations of row indices
    for i, j in combinations(arrivals.index, 2):
        # Compute v_ij
        delta_t_S = (arrivals.loc[i, 'arrival_time_S'] - arrivals.loc[j, 'arrival_time_S']).total_seconds()
        delta_t_P = (arrivals.loc[i, 'arrival_time_P'] - arrivals.loc[j, 'arrival_time_P']).total_seconds()
        
        if delta_t_P != 0:  # Avoid division by zero
            v_ij = delta_t_S / delta_t_P
            
            if v_ij > 0:
                
                results.append({
                    'station_i': arrivals.loc[i, 'station'],
                    'station_j': arrivals.loc[j, 'station'],
                    'v_ij': v_ij
                })

    # Convert results to a DataFrame
    results_df = pd.DataFrame(results)
    return results_df

def plot_vij_histogram(vij_df, cluster,bins=20,output=None):
    """
    Plots a histogram of the v_ij values.

    Parameters:
        vij_df (pd.DataFrame): DataFrame containing v_ij values.
        bins (int): Number of bins for the histogram.
    """
    # Extract v_ij values
    v_ij_values = vij_df['v_ij']
    median = v_ij_values.quantile(0.5)
    
    # Plot the histogram using Seaborn
    plt.figure(figsize=(8, 5))
    sns.histplot(v_ij_values, bins=bins, kde=True, 
                #  stat="density",
                line_kws={'linewidth':2},
                 color='lightcoral', edgecolor='black')
    plt.axvline(x=median,color="black",linestyle='dashed')
    
    # Add the median value as text near the red line
    # plt.text(median-0.005, plt.gca().get_ylim()[1] * 0.5, f"median {median:.2f}", 
    #          color="black", fontsize=12, ha='center', va='center', 
    #          rotation=90)
    plt.text(0.95, 0.95, f"Median = {median:.2f}", 
             color="black", fontsize=12, ha='right', va='top', 
             transform=plt.gca().transAxes, 
            #  backgroundcolor="white"
             )
    
    # Add labels and title
    plt.title(f"R{cluster}", fontsize=16)
    plt.xlabel(r"${v_p}/{v_s}$", fontsize=14)
    plt.ylabel("Counts", fontsize=14)
    
    # Show the plot
    plt.grid(alpha=0.3)
    if output is not None:
        plt.savefig(output, dpi=300, bbox_inches='tight')
    plt.show()

# %% [markdown]
# # c1

# %%
c1 = "/home/emmanuel/ecastillo/dev/delaware/10102024/data_git/clusters/sheng.bna"
root = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/sheng"
catalog_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/sheng/origin.csv"
picks_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/sheng/picks.db"
author = "growclust"
proj = "EPSG:3857"
stations_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/stations/delaware_onlystations_160824.csv"

stations = pd.read_csv(stations_path)
stations_columns = ["network","station","latitude","longitude","elevation"]
stations = stations[stations_columns]
stations["station_index"] = stations.index
stations = Stations(data=stations,xy_epsg=proj)


c1 =pd.read_csv(c1)
c1 = list(zip(c1['lon'], c1['lat']))

eqpicks = EQPicks(root,author=author,
                      xy_epsg=proj,
                      catalog_path=catalog_path,
                      picks_path=picks_path,
                      catalog_header_line=1
                      )
stations.filter_general_region(c1)
cat,picks = eqpicks.get_catalog_with_picks(
                                        general_region=c1
                                           )
cat,picks = prepare_cat2vps(cat.data,picks.data,stations.data)
# print(picks)

all_vps = []
picks = picks.groupby(by="ev_id")
for ev_id, arrivals in picks.__iter__():
    vij_results = compute_vij(arrivals)

    if vij_results.empty:
        continue
    else:
        vij_median = vij_results["v_ij"].median()

    all_vps.append((ev_id,vij_median))
vps = pd.DataFrame(all_vps, columns=["ev_id", "v_ij"])      

cat = pd.merge(cat,vps,how="inner",on="ev_id")
cat.describe()
# Out:
# ['10008g52', '10008mt4', '2000a4kd', '2000a95w', '2000a9zt', '2000a9zw', '2000aa4g', '2000aevc', '2000aevi', '2000amr0', '2000av7x', '2000av9q', '1000av65', '2000avaw', '1000avcx', '1000aved', '1000aveu', '1000awi8', '1000ayf4', 'texnet2017vscb', '2000blfb', '2000c4sj', '1000bsxn', '1000bwx0', 'tx2018bpfgvr', '2000d0n2', '2000dc22', '1000d1ks', '1000d4us', '1000edj5', '1000ehr0', '1000ehtw', '1000eibw', '2000fqqz', '2000h7e7', '2000h7ef', '2000h7eg', '1000h8cj', '2000i7ac', '1000hwcb', '2000isiz', '2000iw9m', '2000j0ym', '2000jety', '1000jaam', '1000jigx', '1000jjh5', '1000jjpx', '1000jk4z', '2000kajq', '2000kc70', '70003ght', '70003ivq', '70003jxk', '600041nu', '70004pzs', '6000501m', '700057yu', '600069ze', '70006nzz', '70006p74', '70006rvb', '70006uqn', '60007ei9', '60007jn0', '60007k4d', '60007m3h', '70007nw9', '70007tcp', '70007thh', '60008a2f', '60008a79', '70008efl', '70008xb9', '70009meb', '7000acqy', '7000aqw9', '6000b219', '6000b8qv', '6000b9sl', '6000ba3f', '7000cbi3', '7000cbkb', '6000cshd', '7000cktv', '7000claj', '7000ckv2', '7000crs3', '6000dcu8', 'texnet2021dqpo', 'texnet2021dqss', 'texnet2021dxtx', 'texnet2021eoja', 'texnet2021flvk', 'texnet2021gffa', 'texnet2021gslw', 'texnet2021icay', 'texnet2021ifxn', 'texnet2021ifxx', 'texnet2021ifyk', 'texnet2021ittk', 'texnet2021kdyd', 'texnet2021kfzx', 'texnet2021kngm', 'texnet2021kqap', 'texnet2021kugg', 'texnet2021kuml', 'texnet2021kzbe', 'texnet2021lfey', 'texnet2021loxf', 'texnet2021lstn', 'texnet2021mgsa', 'texnet2021njus', 'texnet2021oeyf', 'texnet2021oxgn', 'texnet2021ozqg', 'texnet2021paob', 'texnet2021paod', 'texnet2021paoe', 'texnet2021qsxb', 'texnet2021vicn', 'texnet2021vize', 'texnet2021vyua', 'texnet2021vzbx', 'texnet2021wjnw', 'texnet2021wlww', 'texnet2021wooj', 'texnet2021wqqn', 'texnet2021wwdx', 'texnet2021xfcd', 'texnet2021xind', 'texnet2021yhyy', 'texnet2021yikf', 'texnet2021ytov', 'texnet2021yvrj', 'texnet2021zewq', 'texnet2021zmjv', 'texnet2021zqcp', 'texnet2022apfg', 'texnet2022asyl', 'texnet2022bcpc', 'texnet2022beyi', 'texnet2022bfnz', 'texnet2022bizw', 'texnet2022bjaz', 'texnet2022bjbn', 'texnet2022csxs', 'texnet2022dgga', 'texnet2022gdbd', 'texnet2022gdkr', 'texnet2022hedw', 'texnet2022lejk', 'texnet2022lhci', 'texnet2022locs', 'texnet2022lvxs', 'texnet2022mgvc', 'texnet2022mirc', 'texnet2022molh', 'texnet2022nhkc', 'texnet2022nihf', 'texnet2022opsq', 'texnet2022pyqh', 'texnet2022pysr', 'texnet2022pywv', 'texnet2022pzgu', 'texnet2022vegl', 'texnet2022vhoa', 'texnet2022vofn', 'texnet2022wcaa', 'texnet2022webj', 'texnet2022wgxy', 'texnet2022wumx', 'texnet2022wxmz', 'texnet2023cjqe', 'texnet2023iaau', 'texnet2023iaax', 'texnet2023iard', 'texnet2023icjo', 'texnet2023idqz', 'texnet2023jhuq', 'texnet2023jqyr', 'texnet2023jqyx', 'texnet2023lnhp', 'texnet2023nvjr', 'texnet2023rshr', 'texnet2023tizq', 'texnet2023vhfn', 'texnet2023wjvs', 'texnet2023zgpy', 'texnet2024beol', 'texnet2024cbww', 'texnet2024hcpw', 'texnet2024iecf', 'texnet2024iuga', 'texnet2024mczm', 'texnet2024ounp', 'texnet2024outq', 'texnet2024pyvh', 'texnet2024vfft', 'texnet2024wrxq', 'texnet2024wtwo', 'texnet2024xtnn', 'texnet2024zada']
# 2 tables not found
# Not found 2000aevi
# Not found 70006rvb
# Not found 2000avaw
# Not found 7000cktv
# Not found 70003ght
# Not found 7000ckv2
# Not found 60007jn0
# Not found 2000fqqz
# Not found 60007k4d
# Not found 70007thh
# Not found 70003ivq
# Not found 2000c4sj
# Not found 2000blfb
# Not found 6000dcu8
# Not found 2000a9zt
# Not found 1000ehr0
# Not found 1000d4us
# Not found 7000cbkb
# Not found 2000a95w
# Not found 600069ze
# Not found 60007m3h
# Not found 1000bsxn
# Not found 2000av7x
# Not found 1000ayf4
# Not found 2000av9q
# Not found 1000avcx
# Not found 1000aved
# Not found 1000ehtw
# Not found 1000jjh5
# Not found 60007ei9
# Not found 2000h7e7
# Not found 70009meb
# Not found 1000d1ks
# Not found 7000crs3
# Not found 2000iw9m
# Not found 70007nw9
# Not found 6000501m
# Not found 60008a2f
# Not found 6000cshd
# Not found 70008efl
# Not found 2000amr0
# Not found 2000j0ym
# Not found 2000h7eg
# Not found 70007tcp
# Not found 2000aevc
# Not found 6000b9sl
# Not found 2000kajq
# Not found 1000jjpx
# Not found 70006p74
# Not found 2000i7ac
# Not found 2000a9zw
# Not found 70006nzz
# Not found 1000aveu
# Not found 1000av65
# Not found 2000isiz
# Not found 700057yu
# Not found 2000dc22
# Not found 2000aa4g
# Not found 2000d0n2
# Not found 70003jxk
# Not found 1000h8cj
# Not found 70006uqn
# Not found 1000jk4z
# Not found 6000b8qv
# Not found 10008mt4
# Not found 2000h7ef
# Not found 1000edj5
# Not found 2000jety
# Not found 1000awi8
# Not found 1000jigx
# Not found 600041nu
# Not found 1000hwcb
# Not found 6000ba3f
# Not found 6000b219
# Not found 1000jaam
# Not found 7000cbi3
# Not found 1000eibw
# Not found 2000a4kd
# Not found 70004pzs
# Not found 10008g52
# Not found 70008xb9
# Not found 60008a79
# Not found 7000claj
# Not found 2000kc70
# Not found 1000bwx0
# Not found 7000aqw9
# Not found 7000acqy
#                          origin_time  eq_latitude  eq_longitude   magnitude  \
# count                            101   101.000000    101.000000  101.000000
# mean   2022-06-28 11:43:41.553808896    31.138475   -103.270208    2.231683
# min       2021-02-21 18:39:02.169716    31.074737   -103.357267    1.500000
# 25%    2021-08-02 18:08:22.564824064    31.106000   -103.316590    1.900000
# 50%    2022-01-17 22:22:24.499723008    31.132681   -103.266357    2.200000
# 75%    2023-04-25 04:55:45.023870976    31.169746   -103.243998    2.500000
# max       2024-12-21 19:50:52.836758    31.235000   -103.139572    3.500000
# std                              NaN     0.039203      0.051482    0.434495
#
#              v_ij
# count  101.000000
# mean     2.008364
# min      1.021047
# 25%      1.799277
# 50%      1.992779
# 75%      2.166097
# max      4.615191
# std      0.437842

# %%
import numpy as np
cluster = "sheng2"

# output = os.path.join(dw_path,f"data_git/clusters/vps_c{cluster}.csv")
# cat.to_csv(output,index=False)
bins = np.arange(0, 4, 0.1)
Q1 = cat['v_ij'].quantile(0.10)
Q3 = cat['v_ij'].quantile(0.90)
iqr_cat = cat[(cat['v_ij'] >= Q1) & (cat['v_ij'] <= Q3)]
print(iqr_cat.describe())
output = f"/home/emmanuel/ecastillo/dev/delaware/10102024/figures/vps_station/{cluster}.png"
plot_vij_histogram(iqr_cat,cluster,bins=bins,output=output)
# Out:
#                          origin_time  eq_latitude  eq_longitude  magnitude  \
# count                             81    81.000000     81.000000  81.000000
# mean   2022-07-20 04:21:49.650488576    31.139128   -103.268266   2.241975
# min       2021-02-21 18:39:02.169716    31.074737   -103.357267   1.500000
# 25%    2021-08-27 00:39:54.973712896    31.109951   -103.302026   2.000000
# 50%    2022-01-20 04:32:17.377432064    31.131757   -103.265000   2.200000
# 75%    2023-04-26 03:23:17.778747904    31.170198   -103.248000   2.400000
# max       2024-11-19 22:46:44.000847    31.217907   -103.139572   3.500000
# std                              NaN     0.038789      0.051076   0.429786
#
#             v_ij
# count  81.000000
# mean    1.975501
# min     1.578180
# 25%     1.840709
# 50%     1.992779
# 75%     2.108812
# max     2.469352
# std     0.192495

# %% [markdown]
# # c2

# %%
c1 = "/home/emmanuel/ecastillo/dev/delaware/10102024/data_git/clusters/C2.bna"
root = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/aoi/growclust"
catalog_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data_git/clusters/eq_c2.csv"
picks_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/aoi/growclust/picks.db"
author = "growclust"
proj = "EPSG:3857"
stations_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data_git/stations/standard_stations.csv"

stations = pd.read_csv(stations_path)
stations_columns = ["network","station","latitude","longitude","elevation","x[km]","y[km]"]
stations = stations[stations_columns]
stations["station_index"] = stations.index
stations = Stations(data=stations,xy_epsg=proj)


c1 =pd.read_csv(c1)
c1 = list(zip(c1['lon'], c1['lat']))

eqpicks = EQPicks(root,author=author,
                      xy_epsg=proj,
                      catalog_path=catalog_path,
                      picks_path=picks_path
                      )
stations.filter_general_region(c1)
cat,picks = eqpicks.get_catalog_with_picks(
                                        general_region=c1
                                           )
cat,picks = prepare_cat2vps(cat.data,picks.data,stations.data)
# print(picks)

all_vps = []
picks = picks.groupby(by="ev_id")
for ev_id, arrivals in picks.__iter__():
    vij_results = compute_vij(arrivals)

    if vij_results.empty:
        continue
    else:
        vij_median = vij_results["v_ij"].median()

    all_vps.append((ev_id,vij_median))
vps = pd.DataFrame(all_vps, columns=["ev_id", "v_ij"])      

cat = pd.merge(cat,vps,how="inner",on="ev_id")
cat.describe()
# Out:
# Catalog | 4885 events
# Catalog | 4885 events
# 6588 tables not found
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/database.py:105: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(all_dataframes, ignore_index=True)
#                          origin_time  eq_latitude  eq_longitude    magnitude  \
# count                           1819  1819.000000   1819.000000  1819.000000
# mean   2023-06-24 12:23:25.625546496    31.643036   -104.229349     2.059742
# min       2021-12-08 16:24:10.473000    31.522830   -104.380550    -0.060000
# 25%    2023-02-08 02:40:38.083499520    31.615275   -104.296685     1.770000
# 50%       2023-09-24 17:35:09.928000    31.650070   -104.225590     2.020000
# 75%    2024-01-07 11:40:51.297498880    31.669890   -104.173600     2.280000
# max       2024-04-24 16:04:04.320000    31.802610   -104.059690     4.300000
# std                              NaN     0.043868      0.076144     0.434914
#
#               v_ij
# count  1819.000000
# mean      1.732416
# min       0.427676
# 25%       1.620779
# 50%       1.684210
# 75%       1.749546
# max      73.639332
# std       1.717807

# %%
cluster = 2

output = os.path.join(dw_path,f"data_git/clusters/vps_c{cluster}.csv")
cat.to_csv(output,index=False)

Q1 = cat['v_ij'].quantile(0.10)
Q3 = cat['v_ij'].quantile(0.90)
iqr_cat = cat[(cat['v_ij'] >= Q1) & (cat['v_ij'] <= Q3)]
print(iqr_cat.describe())
output = os.path.join(dw_path,f"script/vps/vps_c{cluster}.png")
plot_vij_histogram(iqr_cat,cluster,bins=20,output=output)
# Out:
#                          origin_time  eq_latitude  eq_longitude    magnitude  \
# count                           1455  1455.000000   1455.000000  1455.000000
# mean   2023-07-09 00:48:32.816308992    31.643024   -104.229815     2.058983
# min       2021-12-09 02:22:36.353000    31.522830   -104.380550    -0.060000
# 25%    2023-02-27 18:19:26.421499136    31.615025   -104.296505     1.765000
# 50%       2023-10-12 04:59:59.472000    31.650570   -104.225660     2.020000
# 75%    2024-01-09 18:58:53.238000128    31.670125   -104.174735     2.280000
# max       2024-04-24 16:04:04.320000    31.754490   -104.059690     4.300000
# std                              NaN     0.044173      0.075326     0.425394
#
#               v_ij
# count  1455.000000
# mean      1.683819
# min       1.530482
# 25%       1.635017
# 50%       1.684210
# 75%       1.735242
# max       1.824528
# std       0.068564

# %% [markdown]
# # c3

# %%
c1 = "/home/emmanuel/ecastillo/dev/delaware/10102024/data_git/clusters/C3.bna"
root = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/aoi/growclust"
catalog_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data_git/clusters/eq_c3.csv"
picks_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/aoi/growclust/picks.db"
author = "growclust"
proj = "EPSG:3857"
stations_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data_git/stations/standard_stations.csv"

stations = pd.read_csv(stations_path)
stations_columns = ["network","station","latitude","longitude","elevation","x[km]","y[km]"]
stations = stations[stations_columns]
stations["station_index"] = stations.index
stations = Stations(data=stations,xy_epsg=proj)


c1 =pd.read_csv(c1)
c1 = list(zip(c1['lon'], c1['lat']))

eqpicks = EQPicks(root,author=author,
                      xy_epsg=proj,
                      catalog_path=catalog_path,
                      picks_path=picks_path
                      )
stations.filter_general_region(c1)
cat,picks = eqpicks.get_catalog_with_picks(
                                        general_region=c1
                                           )
cat,picks = prepare_cat2vps(cat.data,picks.data,stations.data)
# print(picks)

all_vps = []
picks = picks.groupby(by="ev_id")
for ev_id, arrivals in picks.__iter__():
    vij_results = compute_vij(arrivals)

    if vij_results.empty:
        continue
    else:
        vij_median = vij_results["v_ij"].median()

    all_vps.append((ev_id,vij_median))
vps = pd.DataFrame(all_vps, columns=["ev_id", "v_ij"])      

cat = pd.merge(cat,vps,how="inner",on="ev_id")
cat.describe()
# Out:
# Catalog | 3263 events
# Catalog | 3263 events
# 7442 tables not found
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/database.py:105: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(all_dataframes, ignore_index=True)
#                          origin_time  eq_latitude  eq_longitude    magnitude  \
# count                           1953  1953.000000   1953.000000  1953.000000
# mean   2023-02-20 08:58:53.836271872    31.620960   -104.017411     2.041941
# min       2021-02-13 10:49:17.548999    31.429460   -104.164110    -0.170000
# 25%    2022-05-14 12:47:04.760999936    31.603620   -104.026060     1.710000
# 50%    2023-07-29 15:21:53.615000064    31.612160   -104.002410     1.970000
# 75%    2023-12-07 02:51:52.351998976    31.639020   -103.979580     2.280000
# max       2024-04-26 02:42:14.877000    31.751630   -103.835610     5.230000
# std                              NaN     0.061636      0.058545     0.483582
#
#               v_ij
# count  1953.000000
# mean      1.681064
# min       0.240580
# 25%       1.617396
# 50%       1.681529
# 75%       1.736842
# max       7.525922
# std       0.257208

# %%
cluster = 3

output = os.path.join(dw_path,f"data_git/clusters/vps_c{cluster}.csv")
cat.to_csv(output,index=False)

Q1 = cat['v_ij'].quantile(0.10)
Q3 = cat['v_ij'].quantile(0.90)
iqr_cat = cat[(cat['v_ij'] >= Q1) & (cat['v_ij'] <= Q3)]
print(iqr_cat.describe())
output = os.path.join(dw_path,f"script/vps/vps_c{cluster}.png")
plot_vij_histogram(iqr_cat,cluster,bins=20,output=output)
# Out:
#                          origin_time  eq_latitude  eq_longitude    magnitude  \
# count                           1561  1561.000000   1561.000000  1561.000000
# mean   2023-04-01 13:33:20.849281792    31.622876   -104.018671     2.061294
# min       2021-02-13 16:21:32.286000    31.429460   -104.164110    -0.170000
# 25%       2022-08-26 17:58:12.284000    31.603600   -104.026630     1.720000
# 50%    2023-09-30 07:53:50.780998912    31.612120   -104.003310     1.990000
# 75%    2023-12-13 09:59:27.187998976    31.642540   -103.979420     2.280000
# max       2024-04-26 02:42:14.877000    31.751040   -103.835610     4.450000
# std                              NaN     0.061938      0.058205     0.480176
#
#               v_ij
# count  1561.000000
# mean      1.677749
# min       1.534236
# 25%       1.634238
# 50%       1.681529
# 75%       1.724191
# max       1.797866
# std       0.060925
