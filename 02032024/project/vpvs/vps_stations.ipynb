# %%
import sys
if 'google.colab' in sys.modules:
    # !git clone  https://github.com/ecastillot/delaware.git ./delaware
    # !pip install obspy

# %%
import sys
import os

version = "10102024"

if 'google.colab' in sys.modules:
    dw_path = os.path.join("/content/delaware",version)
else:
    dw_path = os.path.join("/home/emmanuel/ecastillo/dev/delaware",version)
    
sys.path.append(dw_path)

# %%
from delaware.core.read import EQPicks
from delaware.core.eqviewer import Stations
from delaware.loc.inv import prepare_cat2vps
import pandas as pd
import os
from itertools import combinations
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from itertools import combinations
from typing import Tuple, List, Dict
from scipy.stats import mode

def load_stations(stations_path: str, proj: str) -> object:
    """
    Load station data and return a Stations object.

    Args:
        stations_path (str): Path to the stations CSV file.
        proj (str): EPSG projection for the station data.

    Returns:
        Stations: An object containing station data.
    """
    stations = pd.read_csv(stations_path)
    stations_columns = ["network", "station", "latitude", "longitude", "elevation"]
    stations = stations[stations_columns]
    stations["station_index"] = stations.index
    stations_obj = Stations(data=stations, xy_epsg=proj)
    return stations_obj

def get_single_station(stations: object, station_name: str) -> pd.Series:
    """
    Extract information for a single station by name.

    Args:
        stations (object): Stations object containing station data.
        station_name (str): Name of the station to extract.

    Returns:
        pd.Series: Data for the specified station.
    """
    single_station = stations.data[stations.data["station"] == station_name].iloc[0]
    return single_station

def load_eqpicks(root: str, author: str, proj: str, catalog_path: str, picks_path: str,
                 catalog_header_line=1) -> object:
    """
    Load earthquake picks and return an EQPicks object.

    Args:
        root (str): Root directory for the data.
        author (str): Author name for the picks.
        proj (str): EPSG projection for the picks.
        catalog_path (str): Path to the catalog CSV file.
        picks_path (str): Path to the picks database file.

    Returns:
        EQPicks: An object containing earthquake picks data.
    """
    return EQPicks(root, author=author, xy_epsg=proj, 
                   catalog_header_line=catalog_header_line,
                   catalog_path=catalog_path, picks_path=picks_path)

def process_catalog_and_picks(eq_picks: object, single_station: pd.Series,
                              stations: Stations,r) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Process catalog and picks for a single station.

    Args:
        eq_picks (object): EQPicks object containing picks and catalog data.
        single_station (pd.Series): Data for a single station.

    Returns:
        Tuple[pd.DataFrame, pd.DataFrame]: Processed catalog and picks data.
    """
    src = (single_station.latitude, single_station.longitude, r, None)
    catalog, picks = eq_picks.get_catalog_with_picks(region_from_src=src)
    catalog, picks = prepare_cat2vps(catalog.data, picks.data, stations.data)
    picks = picks[picks["station"] == single_station.station]
    catalog = catalog[catalog['ev_id'].isin(picks['ev_id'])]
    return catalog, picks

def preprocess_picks(picks: pd.DataFrame, catalog: pd.DataFrame) -> pd.DataFrame:
    """
    Preprocess picks data by merging with catalog and calculating arrival times.

    Args:
        picks (pd.DataFrame): Picks data.
        catalog (pd.DataFrame): Catalog data.

    Returns:
        pd.DataFrame: Preprocessed picks data.
    """
    picks_data = pd.merge(picks, catalog, on=["ev_id"])
    picks_data['arrival_time_P'] = pd.to_datetime(picks_data['arrival_time_P']) - pd.to_datetime(picks_data['origin_time'])
    picks_data['arrival_time_S'] = pd.to_datetime(picks_data['arrival_time_S']) - pd.to_datetime(picks_data['origin_time'])
    picks_data['arrival_time_P'] = picks_data['arrival_time_P'].apply(lambda x: x.total_seconds())
    picks_data['arrival_time_S'] = picks_data['arrival_time_S'].apply(lambda x: x.total_seconds())
    return picks_data

def calculate_vij(picks_data: pd.DataFrame) -> pd.DataFrame:
    """
    Calculate v_ij for all combinations of picks.

    Args:
        picks_data (pd.DataFrame): Preprocessed picks data.

    Returns:
        pd.DataFrame: DataFrame containing v_ij results.
    """
    results = []
    good_logs, bad_logs = [], []

    for i, j in combinations(picks_data.index, 2):
        delta_t_S = picks_data.loc[i, 'arrival_time_S'] - picks_data.loc[j, 'arrival_time_S']
        delta_t_P = picks_data.loc[i, 'arrival_time_P'] - picks_data.loc[j, 'arrival_time_P']
        v_ij = delta_t_S / delta_t_P if delta_t_P != 0 else None

        log = {
            "ev_i": picks_data.loc[i, 'ev_id'],
            "ev_j": picks_data.loc[j, 'ev_id'],
            "station": picks_data.loc[i, 'station'],
            "v_ij": v_ij
        }

        if v_ij is not None and v_ij > 0:
            results.append(log)
            good_logs.append(log)
        else:
            bad_logs.append(log)

    print(f"Good: {len(good_logs)}, Bad: {len(bad_logs)}")
    return pd.DataFrame(results)

# %%
root = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/aoi/growclust_and_sheng"
catalog_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/aoi/growclust_and_sheng/origin.csv"
picks_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/aoi/growclust_and_sheng/picks.db"
author = "growclust"
proj = "EPSG:3857"
stations_path = "/home/emmanuel/ecastillo/dev/delaware/02032024/data_git/stations/delaware_onlystations_160824.csv"
# stations_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data_git/stations/standard_stations.csv"

r = 5 #in km
# bins = np.arange(1, 3.02, 0.1)
station_list = ["PB04","PB16"]

custom_palette = {"PB35": "#26fafa", 
                  "PB36": "#2dfa26", 
                  "PB28": "#ad16db", 
                  "PB37": "#1a3be3", 
                  "WB03": "#ffffff", 
                  "SA02": "#f1840f", 
                  "PB24": "#0ea024", 
                  }
# station_list = list(custom_palette.keys())

for station_name in station_list:
    print(station_name)

    stations = load_stations(stations_path, proj)
    print(stations)
    single_station = get_single_station(stations, station_name)

    # Load EQPicks
    eq_picks = load_eqpicks(root, author, proj, catalog_path, picks_path,catalog_header_line=0)

    # Process catalog and picks
    catalog, picks = process_catalog_and_picks(eq_picks, single_station,
                                               stations=stations,
                                               r=r)

    # Preprocess picks
    picks_data = preprocess_picks(picks, catalog)

    # Calculate v_ij
    results_df = calculate_vij(picks_data)
    
    path = os.path.join("/home/emmanuel/ecastillo/dev/delaware/02032024/project/vpvs/stations",f"{station_name}_{r}.csv")
    results_df.to_csv(path,index=False)
    # Q1 = results_df['v_ij'].quantile(0.10)
    # Q3 = results_df['v_ij'].quantile(0.90)
    # iqr_results_df = results_df[(results_df['v_ij'] >= Q1) & (results_df['v_ij'] <= Q3)]
    # print(iqr_results_df.describe())
    # plot_vij_histogram(iqr_results_df,station_name,bins=bins,output=output_fig)
# Out:
# PB04
# Station | 265 stations
# ['texnet2017dnka', 'texnet2017gyzk', 'texnet2017gyzx', 'texnet2017irxv', 'texnet2017kfxu', 'texnet2017kgvj', 'texnet2017mvkh', 'texnet2017nhus', 'texnet2017nnxy', 'texnet2017pecz', 'texnet2017rbyp', 'texnet2017rfou', 'texnet2017rfrv', 'texnet2017rgcy', 'texnet2017rgdg', 'texnet2017rvcp', 'texnet2017sbgt', 'texnet2017syer', 'texnet2017ulcb', 'texnet2017utbj', 'texnet2017uwqg', 'texnet2017uwqy', 'texnet2017vbcd', 'texnet2017vfyr', 'texnet2017vfyu', 'texnet2017vgkt', 'texnet2017vjan', 'texnet2017vnuv', 'texnet2017wdfn', 'texnet2017weal', 'texnet2017wgpf', 'texnet2017whgl', 'texnet2017woyt', 'texnet2017wunb', 'texnet2017wycg', 'texnet2017xwjy', 'texnet2017ymoq', 'texnet2017ynxp', 'texnet2017zbqo', 'texnet2017zhzx', 'texnet2017zova', 'texnet2017zowu', 'texnet2017zoxo', 'texnet2018abkn', 'texnet2018afwt', 'texnet2018afwv', 'texnet2018ahsu', 'texnet2018apho', 'texnet2018bclo', 'texnet2018bedd', 'texnet2018bkej', 'texnet2018bpar', 'texnet2018bprr', 'texnet2018btvi', 'texnet2018cspw', 'texnet2018cyef', 'texnet2018cyom', 'texnet2018cyqj', 'texnet2018deng', 'texnet2018denr', 'texnet2018dfqm', 'texnet2018dilw', 'texnet2018djfs', 'texnet2018dpfu', 'texnet2018dpfv', 'texnet2018emtj', 'texnet2018erye', 'texnet2018esxu', 'texnet2018evqt', 'texnet2018exzf', 'texnet2018fvxe', 'texnet2018fyqf', 'texnet2018gmrc', 'texnet2018hiob', 'texnet2018hlrd', 'texnet2018hmon', 'texnet2018hmop', 'texnet2018ilqm', 'texnet2018ilro', 'texnet2018ipna', 'texnet2018ixin', 'texnet2018jwan', 'texnet2018kafz', 'texnet2018kahd', 'texnet2018kahe', 'texnet2018kami', 'texnet2018kgrm', 'texnet2018kgts', 'texnet2018kimx', 'texnet2018kocd', 'texnet2018kudh', 'texnet2018kudl', 'texnet2018kudw', 'texnet2018kuec', 'texnet2018kujq', 'texnet2018kuka', 'texnet2018kukc', 'texnet2018kukd', 'texnet2018kvoy', 'texnet2018kzxt', 'texnet2018llom', 'texnet2018lthj', 'texnet2018mpah', 'texnet2018mqvv', 'texnet2018nbki', 'texnet2018nedf', 'texnet2018nhkf', 'texnet2018njxh', 'texnet2018nnzo', 'texnet2018oojt', 'texnet2018qjtj', 'texnet2018rdeg', 'texnet2018siff', 'texnet2018sttp', 'texnet2018suyq', 'texnet2018tbcp', 'texnet2018tqhe', 'texnet2018tqyg', 'texnet2018trbr', 'texnet2018tzds', 'texnet2018vaza', 'texnet2018vkpv', 'texnet2018vqwd', 'texnet2018vswh', 'texnet2018vumq', 'texnet2018vxnv', 'texnet2018vxvu', 'texnet2018wakx', 'texnet2018wamg', 'texnet2018wckc', 'texnet2018wdte', 'texnet2018wfvm', 'texnet2018wklr', 'texnet2018wxmj', 'texnet2018wxmk', 'texnet2018wxvx', 'texnet2018xcbw', 'texnet2018xccu', 'texnet2018xcdg', 'texnet2018xdyx', 'texnet2018xfih', 'texnet2018xiag', 'texnet2018xwre', 'texnet2018yduu', 'texnet2018ygyk', 'texnet2018yyay', 'texnet2018zbmr', 'texnet2018zdri', 'texnet2019aasg', 'texnet2019aasi', 'texnet2019aast', 'texnet2019adnb', 'texnet2019aekm', 'texnet2019alcl', 'texnet2019alem', 'texnet2019apxj', 'texnet2019bzcb', 'texnet2019eatx', 'texnet2019eauj', 'texnet2019eekc', 'texnet2019eqlb', 'texnet2019gltr', 'texnet2019hbat', 'texnet2019hlop', 'texnet2019icbw', 'texnet2019igea', 'texnet2019igli', 'texnet2019ilkj', 'texnet2019jbcs', 'texnet2019jbfn', 'texnet2019jnsf', 'texnet2019lqgn', 'texnet2019mvcr', 'texnet2019mxnx', 'texnet2019odyd', 'texnet2019pbft', 'texnet2019pfze', 'texnet2019pkpc', 'texnet2019pnlg', 'texnet2019rlmg', 'texnet2019szsc', 'texnet2019unxy', 'texnet2019vprl', 'texnet2019winl', 'texnet2019wzvt', 'texnet2019xvqn', 'texnet2019xxri', 'texnet2019ygav', 'texnet2019zcdr', 'texnet2019zekb', 'texnet2019zkaz', 'texnet2019zkkf', 'texnet2019zkmd', 'texnet2020ceby', 'texnet2020cfnj', 'texnet2020cfoc', 'texnet2020cfoi', 'texnet2020dabk', 'texnet2020dntl', 'texnet2020doek', 'texnet2020oboj', 'texnet2020oiev', 'texnet2020oife', 'texnet2020ojnn', 'texnet2020okrp', 'texnet2020omcd', 'texnet2020opkk', 'texnet2020otxe', 'texnet2020pdet', 'texnet2020pdyp', 'texnet2020peiy', 'texnet2020phsk', 'texnet2020phuh', 'texnet2020pylf', 'texnet2020pysf', 'texnet2020pyxw', 'texnet2020pyyp', 'texnet2020qbvu', 'texnet2020qfyv', 'texnet2020qgiu', 'texnet2020qkiv', 'texnet2020qlpa', 'te ...
# 13734 tables not found
# Good: 170, Bad: 20
# PB16
# Station | 265 stations
# ['texnet2017epjr', 'texnet2017euuz', 'texnet2017fgec', 'texnet2017gvzz', 'texnet2017gyzk', 'texnet2017gyzx', 'texnet2017gzrs', 'texnet2017htgx', 'texnet2017hvsc', 'texnet2017irri', 'texnet2017jtgj', 'texnet2017kedk', 'texnet2017mxrb', 'texnet2017pbwk', 'texnet2017pecz', 'texnet2017qhqk', 'texnet2017qhqo', 'texnet2017qhsa', 'texnet2017qipz', 'texnet2017qjsf', 'texnet2017qqch', 'texnet2017syia', 'texnet2017szsk', 'texnet2017txie', 'texnet2017urht', 'texnet2017urjq', 'texnet2017vgkt', 'texnet2017woyt', 'texnet2017wsvo', 'texnet2017wtfh', 'texnet2017xahv', 'texnet2017ytmz', 'texnet2017zbox', 'texnet2017zbqo', 'texnet2017zndw', 'texnet2018abkn', 'texnet2018ahsu', 'texnet2018aicz', 'texnet2018akch', 'texnet2018clot', 'texnet2018deng', 'texnet2018denr', 'texnet2018egmt', 'texnet2018eivp', 'texnet2018fdpf', 'texnet2018fesx', 'texnet2018ffpv', 'texnet2018hmon', 'texnet2018hmop', 'texnet2018ieym', 'texnet2018jagu', 'texnet2018jyel', 'texnet2018kbdi', 'texnet2018kbdy', 'texnet2018kdqo', 'texnet2018kfdp', 'texnet2018kfdq', 'texnet2018kfvx', 'texnet2018khka', 'texnet2018kkdb', 'texnet2018krep', 'texnet2018kudh', 'texnet2018kudl', 'texnet2018kuec', 'texnet2018kujq', 'texnet2018kuka', 'texnet2018kukc', 'texnet2018kukd', 'texnet2018kvoy', 'texnet2018kvql', 'texnet2018kvth', 'texnet2018kwbk', 'texnet2018kzxt', 'texnet2018ljhy', 'texnet2018losx', 'texnet2018mavs', 'texnet2018mavt', 'texnet2018mcam', 'texnet2018mdjr', 'texnet2018mjjj', 'texnet2018nedt', 'texnet2018oojt', 'texnet2018rhli', 'texnet2018rhlj', 'texnet2018rhll', 'texnet2018rhnc', 'texnet2018rpnv', 'texnet2018sttp', 'texnet2018tqth', 'texnet2018ugsj', 'texnet2018yvfe', 'texnet2018yzlh', 'texnet2019alem', 'texnet2019eekc', 'texnet2019ehmj', 'texnet2019eict', 'texnet2019eien', 'texnet2019ejzj', 'texnet2019ekaa', 'texnet2019evui', 'texnet2019ewpk', 'texnet2019flon', 'texnet2019fobo', 'texnet2019fofr', 'texnet2019fofs', 'texnet2019foig', 'texnet2019foul', 'texnet2019fpeh', 'texnet2019fpfw', 'texnet2019fprh', 'texnet2019fqsa', 'texnet2019iqsg', 'texnet2019izfk', 'texnet2019jbfn', 'texnet2019jfol', 'texnet2019jfot', 'texnet2019mvcr', 'texnet2019mxnx', 'texnet2019nwpb', 'texnet2019odyd', 'texnet2019orhv', 'texnet2019phlb', 'texnet2019pjop', 'texnet2019qjjf', 'texnet2019qpxp', 'texnet2019qpyj', 'texnet2019sbov', 'texnet2019sbtf', 'texnet2019sdoe', 'texnet2019symq', 'texnet2019tmrx', 'texnet2019urit', 'texnet2019uxmo', 'texnet2019vprl', 'texnet2019vsiz', 'texnet2019wayz', 'texnet2019weef', 'texnet2019winl', 'texnet2019xjpg', 'texnet2019xloq', 'texnet2019ytlx', 'texnet2019yvrj', 'texnet2019yvrk', 'texnet2019yvwa', 'texnet2019ywkf', 'texnet2019yzgd', 'texnet2019yzgg', 'texnet2019zbqw', 'texnet2019zeym', 'texnet2019zkaz', 'texnet2019zkkf', 'texnet2019zkmd', 'texnet2020agwx', 'texnet2020apye', 'texnet2020cazs', 'texnet2020ccff', 'texnet2020ccik', 'texnet2020cfnj', 'texnet2020cpzj', 'texnet2020dabk', 'texnet2020dheq', 'texnet2020dntl', 'texnet2020doek', 'texnet2020dqcx', 'texnet2020ecgz', 'texnet2020enqw', 'texnet2020enyh', 'texnet2020epgs', 'texnet2020fjbb', 'texnet2020htjc', 'texnet2020hvbn', 'texnet2020iiwx', 'texnet2020jvhl', 'texnet2020kbnz', 'texnet2020kxoj', 'texnet2020nrmx', 'texnet2020oiev', 'texnet2020oife', 'texnet2020okde', 'texnet2020okdd', 'texnet2020okrp', 'texnet2020omcd', 'texnet2020pdyp', 'texnet2020peiy', 'texnet2020phio', 'texnet2020phnd', 'texnet2020phuh', 'texnet2020piki', 'texnet2020pjdi', 'texnet2020pjjk', 'texnet2020pjkc', 'texnet2020pkhy', 'texnet2020pzwy', 'texnet2020qank', 'texnet2020qblb', 'texnet2020qbvu', 'texnet2020qern', 'texnet2020qiiv', 'texnet2020qjml', 'texnet2020quzw', 'texnet2020qvwt', 'texnet2020qwvo', 'texnet2020qzrk', 'texnet2020rvqa', 'texnet2020rxlj', 'texnet2020skgz', 'texnet2020smcc', 'texnet2020snql', 'texnet2020svok', 'texnet2020svwu', 'texnet2020svwv', 'texnet2020szkq', 'texnet2020tael', 'texnet2020tepl', 'texnet2020tqtl', 'texnet2020truj', 'texnet2020trxi', 'texnet2020tsqr', 'texnet2020txpw', 'texnet2020ukxc', 'texnet2020unce', 'texnet2020uvlv', 'te ...
# 13720 tables not found
# Good: 351, Bad: 27
