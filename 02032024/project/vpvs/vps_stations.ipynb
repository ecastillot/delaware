# %%
import sys
if 'google.colab' in sys.modules:
    # !git clone  https://github.com/ecastillot/delaware.git ./delaware
    # !pip install obspy

# %%
import sys
import os

version = "10102024"

if 'google.colab' in sys.modules:
    dw_path = os.path.join("/content/delaware",version)
else:
    dw_path = os.path.join("/home/emmanuel/ecastillo/dev/delaware",version)
    
sys.path.append(dw_path)

# %%
from delaware.core.read import EQPicks
from delaware.core.eqviewer import Stations
from delaware.loc.inv import prepare_cat2vps
import pandas as pd
import os
from itertools import combinations
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from itertools import combinations
from typing import Tuple, List, Dict
from scipy.stats import mode

def load_stations(stations_path: str, proj: str) -> object:
    """
    Load station data and return a Stations object.

    Args:
        stations_path (str): Path to the stations CSV file.
        proj (str): EPSG projection for the station data.

    Returns:
        Stations: An object containing station data.
    """
    stations = pd.read_csv(stations_path)
    stations_columns = ["network", "station", "latitude", "longitude", "elevation"]
    stations = stations[stations_columns]
    stations["station_index"] = stations.index
    stations_obj = Stations(data=stations, xy_epsg=proj)
    return stations_obj

def get_single_station(stations: object, station_name: str) -> pd.Series:
    """
    Extract information for a single station by name.

    Args:
        stations (object): Stations object containing station data.
        station_name (str): Name of the station to extract.

    Returns:
        pd.Series: Data for the specified station.
    """
    single_station = stations.data[stations.data["station"] == station_name].iloc[0]
    return single_station

def load_eqpicks(root: str, author: str, proj: str, catalog_path: str, picks_path: str,
                 catalog_header_line=1) -> object:
    """
    Load earthquake picks and return an EQPicks object.

    Args:
        root (str): Root directory for the data.
        author (str): Author name for the picks.
        proj (str): EPSG projection for the picks.
        catalog_path (str): Path to the catalog CSV file.
        picks_path (str): Path to the picks database file.

    Returns:
        EQPicks: An object containing earthquake picks data.
    """
    return EQPicks(root, author=author, xy_epsg=proj, 
                   catalog_header_line=catalog_header_line,
                   catalog_path=catalog_path, picks_path=picks_path)

def process_catalog_and_picks(eq_picks: object, single_station: pd.Series,
                              stations: Stations,r) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Process catalog and picks for a single station.

    Args:
        eq_picks (object): EQPicks object containing picks and catalog data.
        single_station (pd.Series): Data for a single station.

    Returns:
        Tuple[pd.DataFrame, pd.DataFrame]: Processed catalog and picks data.
    """
    src = (single_station.latitude, single_station.longitude, r, None)
    catalog, picks = eq_picks.get_catalog_with_picks(region_from_src=src)
    catalog, picks = prepare_cat2vps(catalog.data, picks.data, stations.data)
    picks = picks[picks["station"] == single_station.station]
    catalog = catalog[catalog['ev_id'].isin(picks['ev_id'])]
    return catalog, picks

def preprocess_picks(picks: pd.DataFrame, catalog: pd.DataFrame) -> pd.DataFrame:
    """
    Preprocess picks data by merging with catalog and calculating arrival times.

    Args:
        picks (pd.DataFrame): Picks data.
        catalog (pd.DataFrame): Catalog data.

    Returns:
        pd.DataFrame: Preprocessed picks data.
    """
    picks_data = pd.merge(picks, catalog, on=["ev_id"])
    picks_data['arrival_time_P'] = pd.to_datetime(picks_data['arrival_time_P']) - pd.to_datetime(picks_data['origin_time'])
    picks_data['arrival_time_S'] = pd.to_datetime(picks_data['arrival_time_S']) - pd.to_datetime(picks_data['origin_time'])
    picks_data['arrival_time_P'] = picks_data['arrival_time_P'].apply(lambda x: x.total_seconds())
    picks_data['arrival_time_S'] = picks_data['arrival_time_S'].apply(lambda x: x.total_seconds())
    return picks_data

def calculate_vij(picks_data: pd.DataFrame) -> pd.DataFrame:
    """
    Calculate v_ij for all combinations of picks.

    Args:
        picks_data (pd.DataFrame): Preprocessed picks data.

    Returns:
        pd.DataFrame: DataFrame containing v_ij results.
    """
    results = []
    good_logs, bad_logs = [], []

    for i, j in combinations(picks_data.index, 2):
        delta_t_S = picks_data.loc[i, 'arrival_time_S'] - picks_data.loc[j, 'arrival_time_S']
        delta_t_P = picks_data.loc[i, 'arrival_time_P'] - picks_data.loc[j, 'arrival_time_P']
        v_ij = delta_t_S / delta_t_P if delta_t_P != 0 else None

        log = {
            "ev_i": picks_data.loc[i, 'ev_id'],
            "ev_j": picks_data.loc[j, 'ev_id'],
            "station": picks_data.loc[i, 'station'],
            "v_ij": v_ij
        }

        if v_ij is not None and v_ij > 0:
            results.append(log)
            good_logs.append(log)
        else:
            bad_logs.append(log)

    print(f"Good: {len(good_logs)}, Bad: {len(bad_logs)}")
    return pd.DataFrame(results)

# %%
root = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/aoi/growclust"
catalog_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/aoi/growclust/origin.csv"
picks_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data/eq/aoi/growclust/picks.db"
author = "growclust"
proj = "EPSG:3857"
stations_path = "/home/emmanuel/ecastillo/dev/delaware/10102024/data_git/stations/standard_stations.csv"

r = 20 #in km
# bins = np.arange(1, 3.02, 0.1)
# station_list = ["PB04","PB16"]

custom_palette = {"PB35": "#26fafa", 
                  "PB36": "#2dfa26", 
                  "PB28": "#ad16db", 
                  "PB37": "#1a3be3", 
                  "WB03": "#ffffff", 
                  "SA02": "#f1840f", 
                  "PB24": "#0ea024", 
                  }
station_list = list(custom_palette.keys())

for station_name in station_list:
    print(station_name)

    stations = load_stations(stations_path, proj)
    print(stations)
    single_station = get_single_station(stations, station_name)

    # Load EQPicks
    eq_picks = load_eqpicks(root, author, proj, catalog_path, picks_path,catalog_header_line=0)

    # Process catalog and picks
    catalog, picks = process_catalog_and_picks(eq_picks, single_station,
                                               stations=stations,
                                               r=r)

    # Preprocess picks
    picks_data = preprocess_picks(picks, catalog)

    # Calculate v_ij
    results_df = calculate_vij(picks_data)
    
    path = os.path.join("/home/emmanuel/ecastillo/dev/delaware/02032024/project/vpvs/stations",f"{station_name}_{r}.csv")
    results_df.to_csv(path,index=False)
    # Q1 = results_df['v_ij'].quantile(0.10)
    # Q3 = results_df['v_ij'].quantile(0.90)
    # iqr_results_df = results_df[(results_df['v_ij'] >= Q1) & (results_df['v_ij'] <= Q3)]
    # print(iqr_results_df.describe())
    # plot_vij_histogram(iqr_results_df,station_name,bins=bins,output=output_fig)
# Out:
# PB35
# Station | 36 stations
# ['texnet2017pvek', 'texnet2017pvnl', 'texnet2017pzzu', 'texnet2017qfsu', 'texnet2017syiz', 'texnet2017tjxk', 'texnet2017ywyv', 'texnet2017zief', 'texnet2017zkfy', 'texnet2017zkpd', 'texnet2017zqdy', 'texnet2018aaks', 'texnet2018aaql', 'texnet2018aeyh', 'texnet2018afwx', 'texnet2018ahln', 'texnet2018aklf', 'texnet2018akyq', 'texnet2018aljz', 'texnet2018alnj', 'texnet2018bfnw', 'texnet2018bqpq', 'texnet2018civz', 'texnet2018ciwq', 'texnet2018cixk', 'texnet2018cjgz', 'texnet2018cmpt', 'texnet2018cmql', 'texnet2018epug', 'texnet2018exph', 'texnet2018fama', 'texnet2018ferr', 'texnet2018fvcw', 'texnet2018fztv', 'texnet2018gfcx', 'texnet2018gvre', 'texnet2018haul', 'texnet2018hgtj', 'texnet2018hyse', 'texnet2018hzng', 'texnet2018hzpl', 'texnet2018ijgv', 'texnet2018iubu', 'texnet2018ivao', 'texnet2018jedg', 'texnet2018jfxj', 'texnet2018jhzf', 'texnet2018jifh', 'texnet2018jilu', 'texnet2018jiqz', 'texnet2018jirn', 'texnet2018jlqa', 'texnet2018jlwj', 'texnet2018jmbb', 'texnet2018jmbd', 'texnet2018jmcn', 'texnet2018jmcs', 'texnet2018jmsl', 'texnet2018jnds', 'texnet2018jnpg', 'texnet2018jnvw', 'texnet2018jqki', 'texnet2018jqoa', 'texnet2018jquy', 'texnet2018jrfu', 'texnet2018jsgv', 'texnet2018jskb', 'texnet2018jviq', 'texnet2018jvlr', 'texnet2018jvsi', 'texnet2018jxsj', 'texnet2018jzzz', 'texnet2018kaad', 'texnet2018kczi', 'texnet2018kdkd', 'texnet2018kgoj', 'texnet2018khox', 'texnet2018khpz', 'texnet2018khxg', 'texnet2018klmp', 'texnet2018kqhp', 'texnet2018kqjw', 'texnet2018kqlh', 'texnet2018kqlm', 'texnet2018kqvj', 'texnet2018ksau', 'texnet2018ksfu', 'texnet2018kvzw', 'texnet2018kywj', 'texnet2018lbvi', 'texnet2018lcpt', 'texnet2018ldur', 'texnet2018ldvv', 'texnet2018ldvz', 'texnet2018ldxt', 'texnet2018ldxx', 'texnet2018ldza', 'texnet2018leko', 'texnet2018lgos', 'texnet2018lvra', 'texnet2018lxfm', 'texnet2018lxgo', 'texnet2018lxhq', 'texnet2018lxjb', 'texnet2018lxnk', 'texnet2018mgnj', 'texnet2018mgtk', 'texnet2018mkgq', 'texnet2018mkgw', 'texnet2018mmri', 'texnet2018mmwj', 'texnet2018mnjh', 'texnet2018mnlz', 'texnet2018mpdm', 'texnet2018mpnu', 'texnet2018mpvf', 'texnet2018mqdj', 'texnet2018mqgn', 'texnet2018mqgp', 'texnet2018mqzr', 'texnet2018mrjy', 'texnet2018mrln', 'texnet2018mtep', 'texnet2018mukk', 'texnet2018mvvy', 'texnet2018mvwh', 'texnet2018mvwl', 'texnet2018mwqw', 'texnet2018mxja', 'texnet2018myau', 'texnet2018namn', 'texnet2018neqx', 'texnet2018nhnv', 'texnet2018nhnw', 'texnet2018nhom', 'texnet2018nhpj', 'texnet2018nhqx', 'texnet2018nirq', 'texnet2018nmvz', 'texnet2018nmxo', 'texnet2018nnno', 'texnet2018noew', 'texnet2018nrrl', 'texnet2018nsgt', 'texnet2018ntao', 'texnet2018nxuk', 'texnet2018nxxo', 'texnet2018nzck', 'texnet2018oaii', 'texnet2018olve', 'texnet2018olvi', 'texnet2018olvs', 'texnet2018onxr', 'texnet2018owwv', 'texnet2018oxjy', 'texnet2018oxti', 'texnet2018oxxb', 'texnet2018oybs', 'texnet2018oyfz', 'texnet2018oyid', 'texnet2018oyiv', 'texnet2018ozgw', 'texnet2018pbef', 'texnet2018pbjk', 'texnet2018pecc', 'texnet2018pegp', 'texnet2018peru', 'texnet2018petc', 'texnet2018pfgf', 'texnet2018pghc', 'texnet2018pglw', 'texnet2018phzo', 'texnet2018pjuu', 'texnet2018plkz', 'texnet2018plud', 'texnet2018pmnx', 'texnet2018pnwz', 'texnet2018pohl', 'texnet2018pqev', 'texnet2018pqet', 'texnet2018pvhg', 'texnet2018pxjk', 'texnet2018qcxe', 'texnet2018qdsc', 'texnet2018qgfb', 'texnet2018qghs', 'texnet2018qglf', 'texnet2018qgro', 'texnet2018qhyp', 'texnet2018qijx', 'texnet2018qjkl', 'texnet2018qkyy', 'texnet2018qmyw', 'texnet2018qxbk', 'texnet2018qyng', 'texnet2018qzhj', 'texnet2018qzms', 'texnet2018rlqg', 'texnet2018rmem', 'texnet2018rnjj', 'texnet2018rnyc', 'texnet2018rnyt', 'texnet2018rqef', 'texnet2018rsnx', 'texnet2018rsqi', 'texnet2018rxvt', 'texnet2018ryaw', 'texnet2018rytc', 'texnet2018seal', 'texnet2018sfbj', 'texnet2018smai', 'texnet2018sqni', 'texnet2018sqnm', 'texnet2018squr', 'texnet2018ssvo', 'texnet2018svxu', 'texnet2018svzc', 'texnet2018szna', 'texnet2018tcai', 'texnet2018tcyg', 'texnet2018tnqq', 'texnet2018tros', 'te ...
# 4225 tables not found
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/database.py:105: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(all_dataframes, ignore_index=True)
# Good: 2730731, Bad: 136084
# PB36
# Station | 36 stations
# ['texnet2017pvek', 'texnet2017pvnl', 'texnet2017pzzu', 'texnet2017qfsu', 'texnet2017syiz', 'texnet2017tjxk', 'texnet2017ywyv', 'texnet2017zief', 'texnet2017zkfy', 'texnet2017zkpd', 'texnet2017zqdy', 'texnet2018aaks', 'texnet2018aaql', 'texnet2018aeyh', 'texnet2018afwx', 'texnet2018ahln', 'texnet2018aklf', 'texnet2018akyq', 'texnet2018aljz', 'texnet2018alnj', 'texnet2018bfnw', 'texnet2018bqpq', 'texnet2018civz', 'texnet2018ciwq', 'texnet2018cixk', 'texnet2018cjgz', 'texnet2018cmpt', 'texnet2018cmql', 'texnet2018epug', 'texnet2018exph', 'texnet2018fama', 'texnet2018ferr', 'texnet2018fvcw', 'texnet2018fztv', 'texnet2018gfcx', 'texnet2018gvre', 'texnet2018haul', 'texnet2018hgtj', 'texnet2018hyse', 'texnet2018hzng', 'texnet2018hzpl', 'texnet2018ijgv', 'texnet2018iubu', 'texnet2018ivao', 'texnet2018jedg', 'texnet2018jfxj', 'texnet2018jhzf', 'texnet2018jifh', 'texnet2018jilu', 'texnet2018jiqz', 'texnet2018jirn', 'texnet2018jlqa', 'texnet2018jlwj', 'texnet2018jmbb', 'texnet2018jmbd', 'texnet2018jmcn', 'texnet2018jmcs', 'texnet2018jmsl', 'texnet2018jnds', 'texnet2018jnpg', 'texnet2018jnvw', 'texnet2018jqki', 'texnet2018jqoa', 'texnet2018jquy', 'texnet2018jrfu', 'texnet2018jsgv', 'texnet2018jskb', 'texnet2018jviq', 'texnet2018jvlr', 'texnet2018jvsi', 'texnet2018jxsj', 'texnet2018jzzz', 'texnet2018kaad', 'texnet2018kczi', 'texnet2018kdkd', 'texnet2018kgoj', 'texnet2018khox', 'texnet2018khpz', 'texnet2018khxg', 'texnet2018klmp', 'texnet2018kqhp', 'texnet2018kqjw', 'texnet2018kqlh', 'texnet2018kqlm', 'texnet2018kqvj', 'texnet2018ksau', 'texnet2018ksfu', 'texnet2018kvzw', 'texnet2018kywj', 'texnet2018lbvi', 'texnet2018lcpt', 'texnet2018ldur', 'texnet2018ldvv', 'texnet2018ldvz', 'texnet2018ldxt', 'texnet2018ldxx', 'texnet2018ldza', 'texnet2018leko', 'texnet2018lgos', 'texnet2018lvra', 'texnet2018lxfm', 'texnet2018lxgo', 'texnet2018lxhq', 'texnet2018lxjb', 'texnet2018lxnk', 'texnet2018mgnj', 'texnet2018mgtk', 'texnet2018mkgq', 'texnet2018mkgw', 'texnet2018mmri', 'texnet2018mmwj', 'texnet2018mnjh', 'texnet2018mnlz', 'texnet2018mpdm', 'texnet2018mpnu', 'texnet2018mpvf', 'texnet2018mqdj', 'texnet2018mqgn', 'texnet2018mqgp', 'texnet2018mqzr', 'texnet2018mrjy', 'texnet2018mrln', 'texnet2018mtep', 'texnet2018mukk', 'texnet2018mvvy', 'texnet2018mvwh', 'texnet2018mvwl', 'texnet2018mwqw', 'texnet2018mxja', 'texnet2018myau', 'texnet2018namn', 'texnet2018neqx', 'texnet2018nhnv', 'texnet2018nhnw', 'texnet2018nhom', 'texnet2018nhpj', 'texnet2018nhqx', 'texnet2018nirq', 'texnet2018nmvz', 'texnet2018nmxo', 'texnet2018nnno', 'texnet2018noew', 'texnet2018nrrl', 'texnet2018nsgt', 'texnet2018ntao', 'texnet2018nxuk', 'texnet2018nxxo', 'texnet2018nzck', 'texnet2018oaii', 'texnet2018olve', 'texnet2018olvi', 'texnet2018olvs', 'texnet2018onxr', 'texnet2018owwv', 'texnet2018oxjy', 'texnet2018oxti', 'texnet2018oxxb', 'texnet2018oybs', 'texnet2018oyfz', 'texnet2018oyid', 'texnet2018oyiv', 'texnet2018ozgw', 'texnet2018pbef', 'texnet2018pbjk', 'texnet2018pecc', 'texnet2018pegp', 'texnet2018peru', 'texnet2018petc', 'texnet2018pfgf', 'texnet2018pghc', 'texnet2018pglw', 'texnet2018phzo', 'texnet2018pjuu', 'texnet2018plkz', 'texnet2018plud', 'texnet2018pmnx', 'texnet2018pnwz', 'texnet2018pohl', 'texnet2018pqev', 'texnet2018pqet', 'texnet2018pvhg', 'texnet2018pxjk', 'texnet2018qcxe', 'texnet2018qdsc', 'texnet2018qgfb', 'texnet2018qghs', 'texnet2018qglf', 'texnet2018qgro', 'texnet2018qhyp', 'texnet2018qijx', 'texnet2018qjkl', 'texnet2018qkyy', 'texnet2018qmyw', 'texnet2018qxbk', 'texnet2018qyng', 'texnet2018qzhj', 'texnet2018qzms', 'texnet2018rlqg', 'texnet2018rmem', 'texnet2018rnjj', 'texnet2018rnyc', 'texnet2018rnyt', 'texnet2018rqef', 'texnet2018rsnx', 'texnet2018rsqi', 'texnet2018rxvt', 'texnet2018ryaw', 'texnet2018rytc', 'texnet2018seal', 'texnet2018sfbj', 'texnet2018smai', 'texnet2018sqni', 'texnet2018sqnm', 'texnet2018squr', 'texnet2018ssvo', 'texnet2018svxu', 'texnet2018svzc', 'texnet2018szna', 'texnet2018tcai', 'texnet2018tcyg', 'texnet2018tnqq', 'texnet2018tros', 'te ...
# 4228 tables not found
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/database.py:105: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(all_dataframes, ignore_index=True)
# Good: 546464, Bad: 28664
# PB28
# Station | 36 stations
# ['texnet2017pvek', 'texnet2017pvnl', 'texnet2017pzzu', 'texnet2017qfsu', 'texnet2017syiz', 'texnet2017tjxk', 'texnet2017ywyv', 'texnet2017zief', 'texnet2017zkfy', 'texnet2017zqdy', 'texnet2018aaks', 'texnet2018aaql', 'texnet2018aeyh', 'texnet2018afwx', 'texnet2018ahln', 'texnet2018aklf', 'texnet2018akyq', 'texnet2018aljz', 'texnet2018alnj', 'texnet2018bfnw', 'texnet2018bqpq', 'texnet2018civz', 'texnet2018ciwq', 'texnet2018cixk', 'texnet2018cjgz', 'texnet2018cmpt', 'texnet2018cmql', 'texnet2018epug', 'texnet2018exph', 'texnet2018fama', 'texnet2018ferr', 'texnet2018fvcw', 'texnet2018fztv', 'texnet2018gfcx', 'texnet2018gvre', 'texnet2018haul', 'texnet2018hgtj', 'texnet2018hyse', 'texnet2018hzng', 'texnet2018hzpl', 'texnet2018ijgv', 'texnet2018iubu', 'texnet2018ivao', 'texnet2018jedg', 'texnet2018jfxj', 'texnet2018jhzf', 'texnet2018jifh', 'texnet2018jilu', 'texnet2018jiqz', 'texnet2018jirn', 'texnet2018jlqa', 'texnet2018jlwj', 'texnet2018jmbb', 'texnet2018jmbd', 'texnet2018jmcn', 'texnet2018jmcs', 'texnet2018jmsl', 'texnet2018jnds', 'texnet2018jnpg', 'texnet2018jnvw', 'texnet2018jqki', 'texnet2018jqoa', 'texnet2018jquy', 'texnet2018jrfu', 'texnet2018jsgv', 'texnet2018jskb', 'texnet2018jviq', 'texnet2018jvlr', 'texnet2018jvsi', 'texnet2018jxsj', 'texnet2018jzzz', 'texnet2018kaad', 'texnet2018kczi', 'texnet2018kdkd', 'texnet2018kgoj', 'texnet2018khox', 'texnet2018khpz', 'texnet2018khxg', 'texnet2018klmp', 'texnet2018kqhp', 'texnet2018kqjw', 'texnet2018kqlh', 'texnet2018kqlm', 'texnet2018kqvj', 'texnet2018ksau', 'texnet2018ksfu', 'texnet2018kvzw', 'texnet2018kywj', 'texnet2018lbvi', 'texnet2018lcpt', 'texnet2018ldur', 'texnet2018ldvv', 'texnet2018ldvz', 'texnet2018ldxt', 'texnet2018ldxx', 'texnet2018ldza', 'texnet2018leko', 'texnet2018lgos', 'texnet2018lvra', 'texnet2018lxfm', 'texnet2018lxgo', 'texnet2018lxhq', 'texnet2018lxjb', 'texnet2018lxnk', 'texnet2018mgnj', 'texnet2018mgtk', 'texnet2018mkgq', 'texnet2018mkgw', 'texnet2018mmri', 'texnet2018mmwj', 'texnet2018mnjh', 'texnet2018mnlz', 'texnet2018mpdm', 'texnet2018mpnu', 'texnet2018mpvf', 'texnet2018mqdj', 'texnet2018mqgn', 'texnet2018mqgp', 'texnet2018mqzr', 'texnet2018mrjy', 'texnet2018mrln', 'texnet2018mtep', 'texnet2018mukk', 'texnet2018mvvy', 'texnet2018mvwh', 'texnet2018mvwl', 'texnet2018mwqw', 'texnet2018mxja', 'texnet2018myau', 'texnet2018namn', 'texnet2018neqx', 'texnet2018nhnv', 'texnet2018nhnw', 'texnet2018nhom', 'texnet2018nhpj', 'texnet2018nhqx', 'texnet2018nirq', 'texnet2018nmvz', 'texnet2018nmxo', 'texnet2018nnno', 'texnet2018noew', 'texnet2018nrrl', 'texnet2018nsgt', 'texnet2018ntao', 'texnet2018nxuk', 'texnet2018nxxo', 'texnet2018nzck', 'texnet2018oaii', 'texnet2018olve', 'texnet2018olvi', 'texnet2018olvs', 'texnet2018onxr', 'texnet2018oxti', 'texnet2018oyiv', 'texnet2018ozgw', 'texnet2018pbef', 'texnet2018pbjk', 'texnet2018pecc', 'texnet2018pegp', 'texnet2018phzo', 'texnet2018pmnx', 'texnet2018pqev', 'texnet2018pqet', 'texnet2018pvhg', 'texnet2018pxjk', 'texnet2018qdsc', 'texnet2018qgfb', 'texnet2018qghs', 'texnet2018qglf', 'texnet2018qgro', 'texnet2018qhyp', 'texnet2018qijx', 'texnet2018qjkl', 'texnet2018qkyy', 'texnet2018qmyw', 'texnet2018qxbk', 'texnet2018qyng', 'texnet2018qzhj', 'texnet2018qzms', 'texnet2018rlqg', 'texnet2018rnyc', 'texnet2018rxvt', 'texnet2018ryaw', 'texnet2018sqni', 'texnet2018sqnm', 'texnet2018squr', 'texnet2018ssvo', 'texnet2018svxu', 'texnet2018svzc', 'texnet2018szna', 'texnet2018tcai', 'texnet2018tcyg', 'texnet2018tnqq', 'texnet2018tros', 'texnet2018tuht', 'texnet2018ujdm', 'texnet2018uqfn', 'texnet2018urlx', 'texnet2018utvy', 'texnet2018uvdw', 'texnet2018uxfw', 'texnet2018uxgb', 'texnet2018vdfv', 'texnet2018vihg', 'texnet2018vijb', 'texnet2018vmtv', 'texnet2018vorl', 'texnet2018vpeu', 'texnet2018vpjz', 'texnet2018vqqj', 'texnet2018vqxz', 'texnet2018vuri', 'texnet2018vzmq', 'texnet2018wajw', 'texnet2018wask', 'texnet2018wdfb', 'texnet2018wdlo', 'texnet2018wdvm', 'texnet2018wefw', 'texnet2018wely', 'texnet2018wipp', 'texnet2018wjvc', 'te ...
# 4925 tables not found
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/database.py:105: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(all_dataframes, ignore_index=True)
# Good: 8372696, Bad: 382324
# PB37
# Station | 36 stations
# ['texnet2017pvek', 'texnet2017pvnl', 'texnet2017pzzu', 'texnet2017qfsu', 'texnet2017syiz', 'texnet2017tjxk', 'texnet2017ywyv', 'texnet2017zief', 'texnet2017zqdy', 'texnet2018aaks', 'texnet2018aaql', 'texnet2018aeyh', 'texnet2018afwx', 'texnet2018ahln', 'texnet2018aklf', 'texnet2018akyq', 'texnet2018aljz', 'texnet2018alnj', 'texnet2018bfnw', 'texnet2018civz', 'texnet2018ciwq', 'texnet2018cixk', 'texnet2018cjgz', 'texnet2018cmpt', 'texnet2018cmql', 'texnet2018exph', 'texnet2018fama', 'texnet2018ferr', 'texnet2018fztv', 'texnet2018gfcx', 'texnet2018gvre', 'texnet2018haul', 'texnet2018hgtj', 'texnet2018hyse', 'texnet2018hzng', 'texnet2018hzpl', 'texnet2018ijgv', 'texnet2018iubu', 'texnet2018ivao', 'texnet2018jedg', 'texnet2018jfxj', 'texnet2018jhzf', 'texnet2018jifh', 'texnet2018jilu', 'texnet2018jiqz', 'texnet2018jirn', 'texnet2018jlqa', 'texnet2018jlwj', 'texnet2018jmbb', 'texnet2018jmbd', 'texnet2018jmcn', 'texnet2018jmcs', 'texnet2018jmsl', 'texnet2018jnds', 'texnet2018jnpg', 'texnet2018jnvw', 'texnet2018jqki', 'texnet2018jqoa', 'texnet2018jquy', 'texnet2018jrfu', 'texnet2018jsgv', 'texnet2018jskb', 'texnet2018jviq', 'texnet2018jvlr', 'texnet2018jvsi', 'texnet2018jxsj', 'texnet2018jzzz', 'texnet2018kaad', 'texnet2018kczi', 'texnet2018kdkd', 'texnet2018kgoj', 'texnet2018khox', 'texnet2018khpz', 'texnet2018khxg', 'texnet2018klmp', 'texnet2018kqhp', 'texnet2018kqlh', 'texnet2018kqlm', 'texnet2018kqvj', 'texnet2018ksau', 'texnet2018ksfu', 'texnet2018kvzw', 'texnet2018kywj', 'texnet2018lbvi', 'texnet2018lcpt', 'texnet2018ldur', 'texnet2018ldvv', 'texnet2018ldvz', 'texnet2018ldxt', 'texnet2018ldxx', 'texnet2018ldza', 'texnet2018leko', 'texnet2018lgos', 'texnet2018lvra', 'texnet2018lxfm', 'texnet2018lxgo', 'texnet2018lxhq', 'texnet2018lxjb', 'texnet2018lxnk', 'texnet2018mgnj', 'texnet2018mgtk', 'texnet2018mkgq', 'texnet2018mkgw', 'texnet2018mmri', 'texnet2018mmwj', 'texnet2018mnjh', 'texnet2018mnlz', 'texnet2018mpdm', 'texnet2018mpnu', 'texnet2018mpvf', 'texnet2018mqdj', 'texnet2018mqgn', 'texnet2018mqgp', 'texnet2018mqzr', 'texnet2018mrjy', 'texnet2018mrln', 'texnet2018mtep', 'texnet2018mukk', 'texnet2018mvvy', 'texnet2018mvwh', 'texnet2018mvwl', 'texnet2018mwqw', 'texnet2018mxja', 'texnet2018myau', 'texnet2018namn', 'texnet2018neqx', 'texnet2018nhnv', 'texnet2018nhnw', 'texnet2018nhom', 'texnet2018nhpj', 'texnet2018nhqx', 'texnet2018nirq', 'texnet2018nmvz', 'texnet2018nmxo', 'texnet2018nnno', 'texnet2018noew', 'texnet2018nrrl', 'texnet2018nsgt', 'texnet2018ntao', 'texnet2018nxuk', 'texnet2018nxxo', 'texnet2018nzck', 'texnet2018oaii', 'texnet2018olve', 'texnet2018olvi', 'texnet2018olvs', 'texnet2018onxr', 'texnet2018oxti', 'texnet2018oyiv', 'texnet2018ozgw', 'texnet2018pbef', 'texnet2018pbjk', 'texnet2018pecc', 'texnet2018pegp', 'texnet2018phzo', 'texnet2018pmnx', 'texnet2018pqev', 'texnet2018pqet', 'texnet2018pvhg', 'texnet2018pxjk', 'texnet2018qdsc', 'texnet2018qgfb', 'texnet2018qghs', 'texnet2018qglf', 'texnet2018qgro', 'texnet2018qhyp', 'texnet2018qijx', 'texnet2018qjkl', 'texnet2018qkyy', 'texnet2018qmyw', 'texnet2018qxbk', 'texnet2018qyng', 'texnet2018qzhj', 'texnet2018qzms', 'texnet2018rnyc', 'texnet2018rxvt', 'texnet2018ryaw', 'texnet2018sqni', 'texnet2018sqnm', 'texnet2018squr', 'texnet2018ssvo', 'texnet2018svxu', 'texnet2018svzc', 'texnet2018szna', 'texnet2018tcai', 'texnet2018tcyg', 'texnet2018tnqq', 'texnet2018tros', 'texnet2018ujdm', 'texnet2018uqfn', 'texnet2018urlx', 'texnet2018utvy', 'texnet2018uvdw', 'texnet2018uxfw', 'texnet2018uxgb', 'texnet2018vdfv', 'texnet2018vmtv', 'texnet2018vorl', 'texnet2018vpeu', 'texnet2018vpjz', 'texnet2018vqqj', 'texnet2018vqxz', 'texnet2018vuri', 'texnet2018vzmq', 'texnet2018wajw', 'texnet2018wask', 'texnet2018wdfb', 'texnet2018wdlo', 'texnet2018wdvm', 'texnet2018wely', 'texnet2018wipp', 'texnet2018wjvc', 'texnet2018wkdc', 'texnet2018wlct', 'texnet2018wxmg', 'texnet2018wyde', 'texnet2018wydi', 'texnet2018wyeg', 'texnet2018wyga', 'texnet2018wyhg', 'texnet2018wyyt', 'texnet2018wzri', 'te ...
# 5615 tables not found
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/database.py:105: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(all_dataframes, ignore_index=True)
# Good: 1527591, Bad: 127699
# WB03
# Station | 36 stations
# ['texnet2017jrka', 'texnet2017kznc', 'texnet2017lziz', 'texnet2017mfrv', 'texnet2017pwsq', 'texnet2017qpcc', 'texnet2017qqza', 'texnet2017upzw', 'texnet2017usyz', 'texnet2017venz', 'texnet2017vhwx', 'texnet2017xsqq', 'texnet2017ynva', 'texnet2018ejhh', 'texnet2018fnma', 'texnet2018fnnh', 'texnet2018gdyl', 'texnet2018gfxc', 'texnet2018iwtm', 'texnet2018jcee', 'texnet2018jybc', 'texnet2018jydi', 'texnet2018jzop', 'texnet2018keux', 'texnet2018kevd', 'texnet2018kevq', 'texnet2018kexa', 'texnet2018keyq', 'texnet2018kfdl', 'texnet2018kftx', 'texnet2018kful', 'texnet2018kkpw', 'texnet2018kwjo', 'texnet2018lowa', 'texnet2018loxa', 'texnet2018lsym', 'texnet2018mrpk', 'texnet2018neqh', 'texnet2018oidu', 'texnet2018qcpa', 'texnet2018tfrh', 'texnet2018tftc', 'texnet2018uaka', 'texnet2018vkhg', 'texnet2018vygw', 'texnet2018wxvk', 'texnet2018xgar', 'texnet2018xriv', 'texnet2018xzbm', 'texnet2018yhub', 'texnet2018zayo', 'texnet2019aqxw', 'texnet2019bcwe', 'texnet2019bhhf', 'texnet2019bvxv', 'texnet2019bvxx', 'texnet2019bwbb', 'texnet2019bwmy', 'texnet2019dilm', 'texnet2019ejpl', 'texnet2019emcv', 'texnet2019gxak', 'texnet2019icuo', 'texnet2019jubc', 'texnet2019jzrl', 'texnet2019kfpo', 'texnet2019kmmc', 'texnet2019kvtx', 'texnet2019kytp', 'texnet2019lcrl', 'texnet2019mmte', 'texnet2019msfw', 'texnet2019mvgo', 'texnet2019nasu', 'texnet2019nort', 'texnet2019nthl', 'texnet2019oqov', 'texnet2019ornr', 'texnet2019oteb', 'texnet2019pawt', 'texnet2019pdlb', 'texnet2019titw', 'texnet2019usfw', 'texnet2019vfqz', 'texnet2019vimg', 'texnet2019vmrs', 'texnet2019vmrx', 'texnet2019vmse', 'texnet2019vqfj', 'texnet2019vuyw', 'texnet2019vvvb', 'texnet2019vwcz', 'texnet2019vwiz', 'texnet2019vwog', 'texnet2019vxsf', 'texnet2019vysx', 'texnet2019wass', 'texnet2019wcmz', 'texnet2019wcna', 'texnet2019wxgj', 'texnet2019xqts', 'texnet2019yodv', 'texnet2020aqum', 'texnet2020bgyr', 'texnet2020bvzp', 'texnet2020bwkd', 'texnet2020bywl', 'texnet2020byyc', 'texnet2020bzet', 'texnet2020bzpf', 'texnet2020bzpy', 'texnet2020bzqt', 'texnet2020bzra', 'texnet2020bzsp', 'texnet2020bztc', 'texnet2020bzua', 'texnet2020bzuh', 'texnet2020bzwq', 'texnet2020bzxs', 'texnet2020bzyc', 'texnet2020bzys', 'texnet2020bzyz', 'texnet2020cdbx', 'texnet2020cdby', 'texnet2020cdet', 'texnet2020cdga', 'texnet2020cdkb', 'texnet2020cdnu', 'texnet2020cdoo', 'texnet2020cdum', 'texnet2020cdut', 'texnet2020ceuo', 'texnet2020cfpr', 'texnet2020cqle', 'texnet2020crnm', 'texnet2020csjm', 'texnet2020cyoo', 'texnet2020cysc', 'texnet2020ddps', 'texnet2020degs', 'texnet2020dgbh', 'texnet2020dhix', 'texnet2020dhke', 'texnet2020dhuz', 'texnet2020diej', 'texnet2020dksu', 'texnet2020dktb', 'texnet2020dkut', 'texnet2020dkux', 'texnet2020dkuz', 'texnet2020dlge', 'texnet2020dqws', 'texnet2020draw', 'texnet2020drsd', 'texnet2020dthz', 'texnet2020dwik', 'texnet2020dwna', 'texnet2020eacm', 'texnet2020engz', 'texnet2020enha', 'texnet2020fajy', 'texnet2020fbzz', 'texnet2020fcas', 'texnet2020fcbn', 'texnet2020fced', 'texnet2020fcgk', 'texnet2020ffbe', 'texnet2020fgal', 'texnet2020fgwg', 'texnet2020fhdj', 'texnet2020fhhz', 'texnet2020fikg', 'texnet2020fona', 'texnet2020fscl', 'texnet2020fscs', 'texnet2020fxhw', 'texnet2020fzzi', 'texnet2020fzzu', 'texnet2020gaaa', 'texnet2020gaab', 'texnet2020gabl', 'texnet2020gaci', 'texnet2020gacu', 'texnet2020gadb', 'texnet2020gadm', 'texnet2020gagp', 'texnet2020gahl', 'texnet2020gaks', 'texnet2020galz', 'texnet2020gamn', 'texnet2020gamu', 'texnet2020ganb', 'texnet2020ganc', 'texnet2020gane', 'texnet2020gany', 'texnet2020gapp', 'texnet2020gapy', 'texnet2020gaqy', 'texnet2020gara', 'texnet2020garh', 'texnet2020garv', 'texnet2020garz', 'texnet2020gasg', 'texnet2020gasi', 'texnet2020gatd', 'texnet2020gaum', 'texnet2020gazk', 'texnet2020gbay', 'texnet2020gbbc', 'texnet2020gbdh', 'texnet2020gbfb', 'texnet2020gbia', 'texnet2020gbig', 'texnet2020gbiz', 'texnet2020gbjq', 'texnet2020gbpe', 'texnet2020gbpn', 'texnet2020gbqp', 'texnet2020gbud', 'texnet2020gbwv', 'texnet2020gcfv', 'texnet2020gcgn', 'te ...
# 6879 tables not found
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/database.py:105: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(all_dataframes, ignore_index=True)
# Good: 614331, Bad: 32622
# SA02
# Station | 36 stations
# ['texnet2017ywyv', 'texnet2017zkfy', 'texnet2017zkpd', 'texnet2017zqdy', 'texnet2018aeyh', 'texnet2018afwx', 'texnet2018aklf', 'texnet2018akyq', 'texnet2018aljz', 'texnet2018alnj', 'texnet2018bqpq', 'texnet2018epug', 'texnet2018exph', 'texnet2018fvcw', 'texnet2018jvsi', 'texnet2018jxsj', 'texnet2018jzzz', 'texnet2018kqjw', 'texnet2018kqvj', 'texnet2018lbvi', 'texnet2018lgos', 'texnet2018lvra', 'texnet2018mgtk', 'texnet2018mkgq', 'texnet2018mkgw', 'texnet2018mpnu', 'texnet2018mtep', 'texnet2018neqh', 'texnet2018neqx', 'texnet2018nzck', 'texnet2018oaii', 'texnet2018odko', 'texnet2018onxr', 'texnet2018owwv', 'texnet2018oxjy', 'texnet2018oxxb', 'texnet2018oybs', 'texnet2018oyfz', 'texnet2018oyid', 'texnet2018ozgw', 'texnet2018ozss', 'texnet2018pecc', 'texnet2018peru', 'texnet2018petc', 'texnet2018pfgf', 'texnet2018pghc', 'texnet2018pglw', 'texnet2018pjuu', 'texnet2018plkz', 'texnet2018plud', 'texnet2018pmnx', 'texnet2018pnwz', 'texnet2018podq', 'texnet2018pohl', 'texnet2018pxjk', 'texnet2018qcxe', 'texnet2018qdsc', 'texnet2018rlqg', 'texnet2018rmem', 'texnet2018rnjj', 'texnet2018rnyc', 'texnet2018rnyt', 'texnet2018rqef', 'texnet2018rsnx', 'texnet2018rsqi', 'texnet2018rytc', 'texnet2018seal', 'texnet2018sfbj', 'texnet2018smai', 'texnet2018ssvo', 'texnet2018szna', 'texnet2018tnqq', 'texnet2018tuht', 'texnet2018ujdm', 'texnet2018uqfn', 'texnet2018urlx', 'texnet2018utvy', 'texnet2018uvdw', 'texnet2018uxfw', 'texnet2018uxgb', 'texnet2018vdfv', 'texnet2018vihg', 'texnet2018vijb', 'texnet2018vzmq', 'texnet2018wask', 'texnet2018wefw', 'texnet2018wkdc', 'texnet2018wuts', 'texnet2018wxya', 'texnet2018wyam', 'texnet2018wycb', 'texnet2018wyde', 'texnet2018wydi', 'texnet2018wyeg', 'texnet2018wyga', 'texnet2018wyhg', 'texnet2018wyyt', 'texnet2018wzut', 'texnet2018wzzq', 'texnet2018xcvw', 'texnet2018xfjr', 'texnet2018xguf', 'texnet2018xlii', 'texnet2018xnzb', 'texnet2018xomg', 'texnet2018xyvr', 'texnet2018ycdr', 'texnet2018ydvt', 'texnet2018ygrq', 'texnet2018yien', 'texnet2018yjww', 'texnet2018ykmy', 'texnet2018ymhk', 'texnet2018ymhw', 'texnet2018ymsk', 'texnet2018yoly', 'texnet2018yovw', 'texnet2018ypet', 'texnet2018ypey', 'texnet2018yrsw', 'texnet2018ysbw', 'texnet2018ysuo', 'texnet2018yvjp', 'texnet2018ywuo', 'texnet2018yyvn', 'texnet2018yzkl', 'texnet2018zaeu', 'texnet2018zbbz', 'texnet2018zbec', 'texnet2018zbfd', 'texnet2018zbhh', 'texnet2018zbiw', 'texnet2018zbwl', 'texnet2018zcmp', 'texnet2018zcoy', 'texnet2018zcqh', 'texnet2018zdjb', 'texnet2018zebn', 'texnet2018zecd', 'texnet2018zekb', 'texnet2018zekw', 'texnet2018zerv', 'texnet2018zgce', 'texnet2018zggu', 'texnet2018zhps', 'texnet2018zkni', 'texnet2018zknj', 'texnet2018znqg', 'texnet2018znrt', 'texnet2018zoir', 'texnet2018zoml', 'texnet2018zonr', 'texnet2018zowy', 'texnet2018zoxo', 'texnet2018zqtf', 'texnet2019aakr', 'texnet2019aarg', 'texnet2019acfb', 'texnet2019acuy', 'texnet2019aede', 'texnet2019aedp', 'texnet2019aeew', 'texnet2019aegj', 'texnet2019ahbm', 'texnet2019aivn', 'texnet2019akyq', 'texnet2019alzl', 'texnet2019amfr', 'texnet2019amjq', 'texnet2019amkp', 'texnet2019amsd', 'texnet2019amuv', 'texnet2019anes', 'texnet2019anoi', 'texnet2019aonu', 'texnet2019apez', 'texnet2019apgy', 'texnet2019aqhy', 'texnet2019aqin', 'texnet2019atsk', 'texnet2019auga', 'texnet2019auhx', 'texnet2019autt', 'texnet2019auvr', 'texnet2019auwc', 'texnet2019auzj', 'texnet2019auzt', 'texnet2019avao', 'texnet2019avpk', 'texnet2019avqe', 'texnet2019avql', 'texnet2019awcb', 'texnet2019awfs', 'texnet2019awwn', 'texnet2019awxj', 'texnet2019axbo', 'texnet2019aydt', 'texnet2019ayfd', 'texnet2019aygu', 'texnet2019aygx', 'texnet2019ayik', 'texnet2019ayma', 'texnet2019aymi', 'texnet2019ayrn', 'texnet2019ayyu', 'texnet2019azxr', 'texnet2019bbal', 'texnet2019bbbk', 'texnet2019bcgn', 'texnet2019bcwe', 'texnet2019bdag', 'texnet2019bdxt', 'texnet2019beam', 'texnet2019beun', 'texnet2019bfaw', 'texnet2019bfen', 'texnet2019bflk', 'texnet2019bhhf', 'texnet2019birt', 'texnet2019bjaw', 'texnet2019bjhp', 'texnet2019bkew', 'te ...
# 3663 tables not found
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/database.py:105: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(all_dataframes, ignore_index=True)
# Good: 5310270, Bad: 225858
# PB24
# Station | 36 stations
# ['texnet2017kznc', 'texnet2017pwsq', 'texnet2017qpcc', 'texnet2017qqza', 'texnet2017upzw', 'texnet2017vhwx', 'texnet2017ynva', 'texnet2018fnma', 'texnet2018fnnh', 'texnet2018gdyl', 'texnet2018gfxc', 'texnet2018iwtm', 'texnet2018jcee', 'texnet2018jybc', 'texnet2018jydi', 'texnet2018jzop', 'texnet2018keux', 'texnet2018kevd', 'texnet2018kevq', 'texnet2018kexa', 'texnet2018keyq', 'texnet2018kfdl', 'texnet2018kftx', 'texnet2018kful', 'texnet2018kkpw', 'texnet2018kwjo', 'texnet2018lowa', 'texnet2018loxa', 'texnet2018mrpk', 'texnet2018neqh', 'texnet2018odko', 'texnet2018oidu', 'texnet2018ozss', 'texnet2018podq', 'texnet2018qcpa', 'texnet2018tfrh', 'texnet2018tftc', 'texnet2018vkhg', 'texnet2018vygw', 'texnet2018wxvk', 'texnet2018xcvw', 'texnet2018xgar', 'texnet2018xriv', 'texnet2018xzbm', 'texnet2018yhub', 'texnet2018zayo', 'texnet2018zerv', 'texnet2019aqxw', 'texnet2019auwc', 'texnet2019awfs', 'texnet2019ayfd', 'texnet2019aymi', 'texnet2019bbbk', 'texnet2019bcwe', 'texnet2019bhhf', 'texnet2019bvxv', 'texnet2019bvxx', 'texnet2019bwbb', 'texnet2019bwdb', 'texnet2019bwmy', 'texnet2019bycx', 'texnet2019bysw', 'texnet2019bzbz', 'texnet2019cewd', 'texnet2019chhv', 'texnet2019ciwy', 'texnet2019cxgz', 'texnet2019dfcm', 'texnet2019dilm', 'texnet2019dqyu', 'texnet2019duzf', 'texnet2019eafw', 'texnet2019eilf', 'texnet2019ejpg', 'texnet2019ejpl', 'texnet2019emcv', 'texnet2019gjdo', 'texnet2019gjdz', 'texnet2019gjev', 'texnet2019gjlm', 'texnet2019gjmd', 'texnet2019gtrl', 'texnet2019gxak', 'texnet2019icuo', 'texnet2019iilo', 'texnet2019jubc', 'texnet2019kfao', 'texnet2019kfpo', 'texnet2019kfpu', 'texnet2019kgbt', 'texnet2019kmmc', 'texnet2019kvtx', 'texnet2019kytp', 'texnet2019lcrl', 'texnet2019msfw', 'texnet2019mvgo', 'texnet2019nasu', 'texnet2019nhnt', 'texnet2019nhzx', 'texnet2019njea', 'texnet2019nnst', 'texnet2019nort', 'texnet2019nthl', 'texnet2019oqov', 'texnet2019ornr', 'texnet2019oteb', 'texnet2019pawt', 'texnet2019pdlb', 'texnet2019qycn', 'texnet2019qydx', 'texnet2019rcrg', 'texnet2019rcue', 'texnet2019rcuv', 'texnet2019rjys', 'texnet2019rkwq', 'texnet2019titw', 'texnet2019tuzt', 'texnet2019usfw', 'texnet2019vfqz', 'texnet2019vimg', 'texnet2019vmrs', 'texnet2019vmrx', 'texnet2019vmse', 'texnet2019vnfa', 'texnet2019vqfj', 'texnet2019vuyw', 'texnet2019vvvb', 'texnet2019vwcz', 'texnet2019vwiz', 'texnet2019vwog', 'texnet2019vxsf', 'texnet2019vysx', 'texnet2019waay', 'texnet2019wass', 'texnet2019wcmz', 'texnet2019wcna', 'texnet2019wjwm', 'texnet2019wwfr', 'texnet2019wxgj', 'texnet2019wxlk', 'texnet2019wxnr', 'texnet2019wxwb', 'texnet2019wxyy', 'texnet2019xcqb', 'texnet2019xeln', 'texnet2019xhaf', 'texnet2019xjaw', 'texnet2019xjou', 'texnet2019xkmz', 'texnet2019xkwi', 'texnet2019xlmh', 'texnet2019xoac', 'texnet2019xqts', 'texnet2019xtwl', 'texnet2019xtxn', 'texnet2019xycu', 'texnet2019yghz', 'texnet2019yodv', 'texnet2019yqik', 'texnet2019yqio', 'texnet2019yqnb', 'texnet2019yrmc', 'texnet2019ysfk', 'texnet2019ysru', 'texnet2019yuzu', 'texnet2019yvwj', 'texnet2019yxzr', 'texnet2019yybi', 'texnet2019yyby', 'texnet2019yyet', 'texnet2019yyfw', 'texnet2019zape', 'texnet2019zayf', 'texnet2019zcii', 'texnet2019zeke', 'texnet2019zekt', 'texnet2019zhap', 'texnet2019zkax', 'texnet2019zmqt', 'texnet2019zohx', 'texnet2020aazg', 'texnet2020acce', 'texnet2020adbh', 'texnet2020afjq', 'texnet2020amop', 'texnet2020apzt', 'texnet2020aqje', 'texnet2020aqum', 'texnet2020auhu', 'texnet2020axhx', 'texnet2020bcja', 'texnet2020bdwl', 'texnet2020bdzt', 'texnet2020bezl', 'texnet2020bfkp', 'texnet2020bgup', 'texnet2020bgyr', 'texnet2020bhbt', 'texnet2020bhlh', 'texnet2020bihh', 'texnet2020biwa', 'texnet2020bkur', 'texnet2020blug', 'texnet2020boia', 'texnet2020bpve', 'texnet2020brsr', 'texnet2020bvzp', 'texnet2020bwkd', 'texnet2020bywl', 'texnet2020byyc', 'texnet2020bzet', 'texnet2020bzpf', 'texnet2020bzpy', 'texnet2020bzqt', 'texnet2020bzra', 'texnet2020bzsp', 'texnet2020bztc', 'texnet2020bzua', 'texnet2020bzuh', 'texnet2020bzwq', 'texnet2020bzxs', 'texnet2020bzyc', 'te ...
# 6136 tables not found
# /home/emmanuel/ecastillo/dev/delaware/10102024/delaware/core/database.py:105: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(all_dataframes, ignore_index=True)
# Good: 1674518, Bad: 72997
